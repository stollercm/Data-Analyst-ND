# %% [markdown]
# ### mapparser.py

# %%
import xml.etree.cElementTree as ET
import pprint
from collections import defaultdict


def count_tags(filename):
    osm_file = open(filename, "r")
    tags = defaultdict(int)
    for event, elem in ET.iterparse(osm_file):
        tag = elem.tag
        tags[tag] += 1
    return tags


tags = count_tags('cincinnati_ohio.osm')
pprint.pprint(dict(tags))
# Out:
# {'bounds': 1,
#  'member': 14855,
#  'nd': 2450908,
#  'node': 1985255,
#  'osm': 1,
#  'relation': 1176,
#  'tag': 765119,
#  'way': 270492}

# %%
import xml.etree.cElementTree as ET
import pprint
from collections import defaultdict

def node_tag_type(filename):
    node_tags = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if element.tag == "node":
            for child in element:
                if child.tag == "tag":
                    tag = child.attrib["k"]
                    node_tags[tag] += 1
    return node_tags

node_tags = node_tag_type('cincinnati_ohio.osm')
print "Number of distinct node tags: ", len(node_tags)
pprint.pprint(dict(node_tags))
# Out:
# Number of distinct node tags:  316
# {'FIXME': 20,
#  'USEPA': 1,
#  'abandoned:railway': 1,
#  'access': 132,
#  'addr:city': 153,
#  'addr:country': 35,
#  'addr:floor': 1,
#  'addr:full': 11,
#  'addr:housename': 7,
#  'addr:housenumber': 221,
#  'addr:postcode': 173,
#  'addr:state': 287,
#  'addr:street': 231,
#  'addr:suite': 1,
#  'addr:unit': 3,
#  'aeroway': 35,
#  'aeroway:historic': 7,
#  'alt_name': 50,
#  'alt_name:es': 1,
#  'alt_name:zh': 1,
#  'amenity': 2856,
#  'amenity:coming_soon': 1,
#  'amenity:historic': 399,
#  'artwork:type': 1,
#  'artwork_type': 4,
#  'atm': 8,
#  'attribution': 7,
#  'backrest': 41,
#  'barrier': 297,
#  'bell:diameter': 1,
#  'bell:service_times': 1,
#  'bell:weight': 1,
#  'bench': 1,
#  'bicycle': 12,
#  'bicycle_parking': 18,
#  'bollard': 6,
#  'brand': 19,
#  'building': 100,
#  'building:historic': 5,
#  'building:levels': 3,
#  'building:part': 2,
#  'bus': 1,
#  'canoe': 2,
#  'capacity': 80,
#  'cargo': 2,
#  'census:population': 91,
#  'clothes': 1,
#  'club': 1,
#  'collection_times': 1,
#  'colour': 5,
#  'communication:mobile_phone': 1,
#  'compressed_air:valves': 1,
#  'construction': 2,
#  'covered': 94,
#  'craft': 5,
#  'created_by': 241,
#  'crossing': 463,
#  'crossing:light': 1,
#  'cuisine': 355,
#  'cuisine:coming_soon': 1,
#  'cycleway': 10,
#  'delivery': 9,
#  'denomination': 426,
#  'denomination:historic': 1,
#  'denotation': 33,
#  'description': 31,
#  'designation': 3,
#  'diet:vegetarian': 1,
#  'direction': 2,
#  'dispensing': 9,
#  'display': 1,
#  'distance': 1,
#  'disused:amenity': 8,
#  'disused:highway': 1,
#  'disused:operator': 1,
#  'disused:railway': 3,
#  'disused:shop': 2,
#  'drinkable': 6,
#  'drinking_water': 2,
#  'drive_through': 2,
#  'ele': 2359,
#  'ele:msl': 1,
#  'ele:source': 1,
#  'email': 2,
#  'emergency': 14,
#  'end_date': 1,
#  'entrance': 161,
#  'etymology': 1,
#  'exit_to': 197,
#  'exit_to:left': 1,
#  'facebook': 2,
#  'faces': 1,
#  'fax': 3,
#  'fee': 19,
#  'fireplace': 5,
#  'fixme': 7,
#  'flag:name': 7,
#  'flag:type': 31,
#  'floor': 1,
#  'food': 1,
#  'foot': 10,
#  'footway': 14,
#  'gay': 4,
#  'generator:method': 1,
#  'generator:output:electricity': 1,
#  'generator:source': 3,
#  'generator:type': 1,
#  'genus': 7,
#  'gnis:Class': 481,
#  'gnis:County': 484,
#  'gnis:County_num': 484,
#  'gnis:ST_alpha': 484,
#  'gnis:ST_num': 484,
#  'gnis:county_id': 1701,
#  'gnis:county_name': 184,
#  'gnis:created': 1737,
#  'gnis:edited': 119,
#  'gnis:feature_id': 1890,
#  'gnis:feature_type': 36,
#  'gnis:id': 478,
#  'gnis:import_uuid': 143,
#  'gnis:reviewed': 147,
#  'gnis:state_id': 1701,
#  'group_only': 5,
#  'health_specialty:acupuncture': 1,
#  'healthcare': 2,
#  'healthcare:speciality': 1,
#  'healthcare:specialty': 4,
#  'height': 1,
#  'hgv': 2,
#  'highway': 27061,
#  'highway:future': 1,
#  'highway:historic': 2,
#  'historic': 494,
#  'historic:civilization': 2,
#  'historic_1': 1,
#  'horse': 3,
#  'image': 1,
#  'import_uuid': 468,
#  'impromptu': 5,
#  'indoor': 10,
#  'information': 4,
#  'internet_access': 7,
#  'internet_access:fee': 1,
#  'is_in': 493,
#  'is_in:city': 5,
#  'is_in:continent': 1,
#  'is_in:country': 6,
#  'is_in:county': 3,
#  'is_in:state': 5,
#  'is_in:state_code': 1,
#  'junction': 1,
#  'landuse': 51,
#  'landuse:historic': 13,
#  'layer': 6,
#  'leaf_cycle': 1,
#  'leaf_type': 1,
#  'leisure': 217,
#  'leisure:historic': 16,
#  'level': 41,
#  'lit': 2,
#  'loc_name': 22,
#  'man_made': 671,
#  'man_made:historic': 1,
#  'map_size': 3,
#  'map_type': 3,
#  'material': 13,
#  'microbrewery': 10,
#  'min_height': 1,
#  'monument': 2,
#  'motor_vehicle': 11,
#  'motorcar': 3,
#  'motorcycle': 2,
#  'music': 1,
#  'name': 6407,
#  'name:ar': 1,
#  'name:backward': 1,
#  'name:bg': 3,
#  'name:en': 2,
#  'name:en:pronunciation': 1,
#  'name:es': 1,
#  'name:fa': 1,
#  'name:forward': 1,
#  'name:future': 1,
#  'name:he': 1,
#  'name:historical': 1,
#  'name:ja': 3,
#  'name:ka': 1,
#  'name:ko': 1,
#  'name:la': 1,
#  'name:lt': 1,
#  'name:mr': 1,
#  'name:os': 1,
#  'name:pronunciation': 1,
#  'name:ru': 5,
#  'name:sr': 1,
#  'name:ta': 1,
#  'name:uk': 2,
#  'name:vi': 2,
#  'name:zh': 5,
#  'natural': 504,
#  'network': 162,
#  'noexit': 12,
#  'noref': 5,
#  'note': 159,
#  'note2': 3,
#  'office': 58,
#  'official_name': 1,
#  'old_name': 544,
#  'old_name1': 2,
#  'old_name:de': 2,
#  'old_name:en': 1,
#  'old_name:vi': 1,
#  'old_ref': 3,
#  'opening_hours': 86,
#  'opening_hours:url': 4,
#  'opentable': 1,
#  'operator': 1056,
#  'operator:historic': 2,
#  'organic': 1,
#  'outdoor_seating': 1,
#  'park_ride': 2,
#  'parking': 8,
#  'passenger_information_display': 3,
#  'payment:bitcoin': 7,
#  'payment:coins': 1,
#  'pedalboat_rental': 1,
#  'phone': 87,
#  'place': 527,
#  'place:historic': 3,
#  'place_name': 1,
#  'population': 96,
#  'population:date': 4,
#  'postal_code': 5,
#  'power': 3320,
#  'psv': 1,
#  'public_transport': 5,
#  'railway': 549,
#  'railway:future': 9,
#  'recycling:batteries': 3,
#  'recycling:cans': 4,
#  'recycling:clothes': 4,
#  'recycling:glass': 4,
#  'recycling:glass_bottles': 1,
#  'recycling:paper': 6,
#  'recycling:plastic': 1,
#  'recycling:scrap_metal': 3,
#  'recycling_type': 3,
#  'ref': 237,
#  'ref:left': 4,
#  'ref:right': 6,
#  'religion': 763,
#  'route_ref': 5,
#  'scout': 8,
#  'seasonal': 1,
#  'seating': 1,
#  'seats': 5,
#  'second_hand': 2,
#  'service': 1,
#  'service:bicycle:chain_tool': 7,
#  'service:bicycle:diy': 2,
#  'service:bicycle:pump': 5,
#  'service:bicycle:rental': 2,
#  'shelter': 5,
#  'shelter_type': 20,
#  'shop': 519,
#  'shop:future': 1,
#  'shop:historic': 16,
#  'shop:historical': 1,
#  'short_name': 4,
#  'sign': 1,
#  'siren:purpose': 5,
#  'siren:type': 5,
#  'sloped_curb': 11,
#  'smoking': 7,
#  'social_facility:for': 1,
#  'source': 623,
#  'source:name': 1,
#  'sport': 40,
#  'start_date': 10,
#  'stationary': 2,
#  'supervised': 5,
#  'support': 1,
#  'tactile_paving': 11,
#  'takeaway': 8,
#  'tiger:county': 1,
#  'tiger:tlid': 1,
#  'tiger:upload_uuid': 1,
#  'toilets:disposal': 3,
#  'tomb': 1,
#  'tourism': 114,
#  'tower:type': 8,
#  'trade': 1,
#  'traffic_calming': 143,
#  'traffic_sign:backward': 2,
#  'traffic_sign:forward': 3,
#  'traffic_signals': 1,
#  'training': 4,
#  'tram': 2,
#  'twitter': 1,
#  'type': 36,
#  'url': 2,
#  'vending': 4,
#  'visibility': 1,
#  'voltage-high': 14,
#  'voltage-low': 8,
#  'waterway': 72,
#  'waterway:historic': 3,
#  'website': 262,
#  'website:zh': 1,
#  'wheelchair': 26,
#  'wifi': 13,
#  'wikipedia': 35,
#  'wood': 1,
#  'wpt_description': 1,
#  'yelp': 1}

# %%
def way_tag_type(filename):
    way_tags = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if element.tag == "way":
            for child in element:
                if child.tag == "tag":
                    tag = child.attrib["k"]
                    way_tags[tag] += 1
    return way_tags

way_tags = way_tag_type('cincinnati_ohio.osm')
print "Number of distinct way tags: ", len(way_tags)
pprint.pprint(dict(way_tags))
# Out:
# Number of distinct way tags:  460
# {'FIXME': 49,
#  'FIXME:railway': 1,
#  'FIXME:ref': 9,
#  'HFCS': 1,
#  'NHS': 293,
#  'abandoned': 1,
#  'abandoned:highway': 6,
#  'abandoned:service': 1,
#  'abutters': 65,
#  'access': 4386,
#  'access_control': 112,
#  'accuracy:meters': 1,
#  'addr:city': 7217,
#  'addr:country': 3826,
#  'addr:county': 228,
#  'addr:door': 1,
#  'addr:full': 12,
#  'addr:housename': 28,
#  'addr:housenumber': 974,
#  'addr:interpolation': 11,
#  'addr:postcode': 6842,
#  'addr:state': 6293,
#  'addr:street': 7540,
#  'addr:subdistrict': 1,
#  'admin_level': 765,
#  'advertising': 1,
#  'aeroway': 269,
#  'aeroway:disused': 2,
#  'aeroway:historic': 3,
#  'agricultural': 1,
#  'alt': 1,
#  'alt_name': 1213,
#  'alt_name:en': 2,
#  'alt_name:es': 1,
#  'alt_name:historic': 2,
#  'alt_name:vi': 1,
#  'altccess': 1,
#  'amenity': 5409,
#  'amenity:historic': 52,
#  'animal': 1,
#  'area': 394,
#  'atm': 28,
#  'attraction': 58,
#  'attribution': 37,
#  'automated': 2,
#  'barrier': 582,
#  'baseball': 1,
#  'basin': 2,
#  'bicycle': 1765,
#  'boat': 254,
#  'border_type': 124,
#  'boundary': 846,
#  'brand': 53,
#  'bridge': 2216,
#  'bridge:structure': 2,
#  'buffet': 1,
#  'building': 169113,
#  'building:color': 1,
#  'building:colour': 117,
#  'building:height': 184,
#  'building:height:underground': 3,
#  'building:historic': 1,
#  'building:levels': 2950,
#  'building:levels:underground': 18,
#  'building:material': 238,
#  'building:min_height': 13,
#  'building:min_level': 4,
#  'building:min_levels': 16,
#  'building:part': 284,
#  'building_1': 1,
#  'buliding:min_height': 1,
#  'bus': 3,
#  'cables': 84,
#  'capacity': 40,
#  'city': 1,
#  'colour': 5,
#  'construction': 71,
#  'contact:email': 1,
#  'contact:phone': 5,
#  'contact:website': 5,
#  'contamination': 1,
#  'contents': 1,
#  'conveying': 4,
#  'corridor': 3,
#  'county': 3,
#  'covered': 39,
#  'craft': 4,
#  'created_by': 7472,
#  'crop': 2,
#  'cuisine': 441,
#  'cuisine:historic': 1,
#  'cutting': 102,
#  'cycleway': 389,
#  'cycleway:left': 1,
#  'cycleway:right': 7,
#  'deep_draft': 1,
#  'delivery': 7,
#  'denomination': 388,
#  'denomination:historic': 2,
#  'description': 29,
#  'designation': 4,
#  'dine_in': 1,
#  'dispensing': 55,
#  'disused': 4,
#  'disused:aeroway': 4,
#  'disused:amenity': 1,
#  'disused:brand': 1,
#  'disused:building': 3,
#  'disused:highway': 10,
#  'disused:phone': 1,
#  'disused:shop': 1,
#  'disused:website': 1,
#  'dog': 1,
#  'drinking_water': 1,
#  'drive_in': 1,
#  'drive_through': 13,
#  'duration': 1,
#  'ele': 1117,
#  'electrified': 508,
#  'email': 3,
#  'embankment': 107,
#  'emergency': 9,
#  'end_date': 3,
#  'entrance': 2,
#  'es': 1,
#  'est_width': 1,
#  'etymology': 4,
#  'faa': 1,
#  'faa:historic': 1,
#  'fax': 9,
#  'fee': 82,
#  'fence_type': 1,
#  'fireplace': 1,
#  'fixme': 14,
#  'food': 2,
#  'foot': 3958,
#  'footway': 248,
#  'ford': 2,
#  'frequency': 131,
#  'from': 1,
#  'fuel:biodiesel': 1,
#  'fuel:biogas': 1,
#  'fuel:diesel': 1,
#  'fut_ref': 8,
#  'future:operator': 1,
#  'garden:type': 1,
#  'gauge': 506,
#  'gay': 1,
#  'gender': 1,
#  'generator:method': 1,
#  'generator:output:electricity': 16,
#  'generator:source': 21,
#  'gnis:Class': 9,
#  'gnis:County': 9,
#  'gnis:County_num': 9,
#  'gnis:ST_alpha': 9,
#  'gnis:ST_num': 9,
#  'gnis:county_id': 969,
#  'gnis:county_name': 155,
#  'gnis:created': 978,
#  'gnis:edited': 96,
#  'gnis:feature_id': 1107,
#  'gnis:feature_type': 9,
#  'gnis:id': 9,
#  'gnis:import_uuid': 128,
#  'gnis:modified': 1,
#  'gnis:reviewed': 14,
#  'gnis:state': 91,
#  'gnis:state_id': 973,
#  'gnis:street': 1,
#  'golf': 897,
#  'group_only': 1,
#  'handrail': 1,
#  'health_specialty': 1,
#  'healthcare': 1,
#  'healthcare:specialty': 2,
#  'height': 23,
#  'hgv': 1582,
#  'hgv:national_network': 644,
#  'hgv:state_network': 94,
#  'highway': 70866,
#  'highway:historic': 1,
#  'historic': 88,
#  'historic:civilization': 1,
#  'historic:status': 1,
#  'historic:url': 1,
#  'history': 23,
#  'horse': 982,
#  'hrhp': 1,
#  'iata': 2,
#  'icao': 3,
#  'image': 1,
#  'import_uuid': 7,
#  'impromptu': 1,
#  'incline': 29,
#  'indoor': 18,
#  'industrial': 2,
#  'intermittent': 3,
#  'internet_access': 3,
#  'is_in': 16,
#  'junction': 121,
#  'landmark': 1,
#  'landuse': 4701,
#  'landuse:Historical': 1,
#  'landuse:historic': 1,
#  'lane': 1,
#  'lanes': 5235,
#  'lanes:backward': 4,
#  'lanes:forward': 4,
#  'layer': 878,
#  'lcn_ref': 34,
#  'leaf_cycle': 1,
#  'leisure': 6732,
#  'leisure:historic': 3,
#  'level': 4,
#  'line': 1,
#  'lit': 223,
#  'loc_name': 181,
#  'loc_ref': 1,
#  'location': 14,
#  'man_made': 243,
#  'man_made:historic': 1,
#  'material': 1,
#  'maxaxles': 1,
#  'maxspeed': 4144,
#  'maxspeed:advisory': 1,
#  'maxspeed:conditional': 7,
#  'maxspeed:source': 147,
#  'meadow': 1,
#  'microbrewery': 12,
#  'military': 3,
#  'min_height': 3,
#  'mine': 1,
#  'mooring': 2,
#  'motor_vehicle': 439,
#  'motor_vehicle:conditional': 2,
#  'motorcar': 50,
#  'motorcycle': 1,
#  'motorhome': 1,
#  'motorroad': 20,
#  'mtb:scale': 14,
#  'name': 40923,
#  'name:de': 4,
#  'name:en': 7,
#  'name:es': 2,
#  'name:etymology:wikidata': 1,
#  'name:fa': 1,
#  'name:fr': 2,
#  'name:he': 1,
#  'name:hi': 1,
#  'name:historical': 1,
#  'name:ja': 5,
#  'name:ko': 1,
#  'name:la': 1,
#  'name:left': 300,
#  'name:pl': 1,
#  'name:pt': 1,
#  'name:right': 300,
#  'name:ru': 3,
#  'name:sjw': 1,
#  'name:source': 25,
#  'name:vi': 3,
#  'name:zh': 1,
#  'name_1': 956,
#  'name_2': 52,
#  'name_3': 7,
#  'nat_ref': 27,
#  'natural': 10150,
#  'network': 1,
#  'nist:fips_code': 1,
#  'nist:state_fips': 1,
#  'note': 327,
#  'note2': 4,
#  'note:lanes': 44,
#  'note:maxspeed': 1,
#  'note:old_railway_operator': 395,
#  'nris_id': 1,
#  'nwn_ref': 1,
#  'odbl': 5,
#  'office': 59,
#  'official_name': 49,
#  'old_etymology': 1,
#  'old_name': 621,
#  'old_name:vi': 1,
#  'old_name_1': 26,
#  'old_railway_operator': 581,
#  'old_ref': 135,
#  'old_ref:fap': 634,
#  'old_website': 1,
#  'on': 1,
#  'oneway': 8047,
#  'opening_hours': 54,
#  'opening_hours:url': 1,
#  'operator': 1653,
#  'operator:historic': 10,
#  'organic': 2,
#  'outdoor_seating': 2,
#  'park:type': 19,
#  'park_ride': 25,
#  'parking': 1191,
#  'parking:condition:both': 2,
#  'parking:condition:both:maxstay': 1,
#  'parking:condition:right': 4,
#  'parking:condition:right:maxstay': 4,
#  'parking:lane:both': 2,
#  'parking:lane:left': 2,
#  'parking:lane:right': 8,
#  'paved': 1,
#  'payment:bitcoin': 2,
#  'phone': 139,
#  'place': 46,
#  'place:historic': 1,
#  'playground': 2,
#  'postal_code': 1,
#  'power': 453,
#  'power_source': 2,
#  'proposed': 20,
#  'protect_id': 2,
#  'protection_title': 1,
#  'psv': 38,
#  'public_transport': 4,
#  'railway': 1888,
#  'ramp': 1,
#  'ramp:bicycle': 1,
#  'rcn_ref': 170,
#  'recycling:cans': 2,
#  'recycling:clothes': 2,
#  'recycling:computers': 1,
#  'recycling:glass': 2,
#  'recycling:glass_bottles': 1,
#  'recycling:paper': 2,
#  'recycling:plastic': 1,
#  'recycling_type': 1,
#  'ref': 2934,
#  'ref:NRHP': 1,
#  'ref:NRIS': 1,
#  'ref:nass': 1,
#  'ref_1': 1,
#  'reg_name': 221,
#  'regional_name': 1,
#  'religion': 770,
#  'rental': 1,
#  'resource': 2,
#  'retreat': 1,
#  'retreat:for': 1,
#  'retreat:operator': 1,
#  'roof:colour': 85,
#  'roof:height': 24,
#  'roof:levels': 62,
#  'roof:material': 80,
#  'roof:orientation': 10,
#  'roof:shape': 79,
#  'roof:slope:direction': 25,
#  'roof:surface': 2,
#  'route': 1,
#  'ruins': 1,
#  'rwn_ref': 1,
#  'sac_scale': 5,
#  'school': 1,
#  'school_irn': 1,
#  'scout': 2,
#  'seasonal': 1,
#  'second_hand': 3,
#  'segregated': 14,
#  'self_service': 2,
#  'service': 10844,
#  'shelter_type': 10,
#  'ship': 1,
#  'shop': 730,
#  'shop:historic': 5,
#  'short_name': 142,
#  'shoulder': 1,
#  'shoulder:width': 1,
#  'sidewalk': 1582,
#  'site_type': 1,
#  'smoking': 38,
#  'smoothness': 9,
#  'social_facility': 11,
#  'social_facility:for': 8,
#  'source': 2417,
#  'source:access_control': 112,
#  'source:deep_draft': 1,
#  'source:hgv:national_network': 644,
#  'source:hgv:state_network': 90,
#  'source:maxspeed': 21,
#  'source:name': 8,
#  'source:official_name': 1,
#  'source:old_ref:fap': 631,
#  'source:oneway': 1,
#  'sport': 4916,
#  'start_date': 15,
#  'step_count': 7,
#  'stretcher': 1,
#  'studio': 3,
#  'substance': 3,
#  'substation': 9,
#  'supervised': 21,
#  'surface': 2255,
#  'takeaway': 9,
#  'theatre:type': 1,
#  'tiger:cfcc': 34582,
#  'tiger:county': 34596,
#  'tiger:name_base': 30619,
#  'tiger:name_base_1': 2472,
#  'tiger:name_base_2': 351,
#  'tiger:name_base_3': 90,
#  'tiger:name_direction_prefix': 1340,
#  'tiger:name_direction_prefix_1': 50,
#  'tiger:name_direction_prefix_2': 8,
#  'tiger:name_direction_prefix_3': 2,
#  'tiger:name_direction_suffix': 73,
#  'tiger:name_type': 28191,
#  'tiger:name_type_1': 1018,
#  'tiger:name_type_2': 51,
#  'tiger:name_type_3': 16,
#  'tiger:reviewed': 33270,
#  'tiger:separated': 6454,
#  'tiger:source': 7743,
#  'tiger:tlid': 7737,
#  'tiger:upload_uuid': 7737,
#  'tiger:zip_left': 23255,
#  'tiger:zip_left_1': 543,
#  'tiger:zip_left_2': 136,
#  'tiger:zip_left_3': 51,
#  'tiger:zip_left_4': 13,
#  'tiger:zip_right': 22509,
#  'tiger:zip_right_1': 224,
#  'tiger:zip_right_2': 46,
#  'tiger:zip_right_3': 23,
#  'tiger:zip_right_4': 6,
#  'toilets:disposal': 4,
#  'toll': 1,
#  'tourism': 239,
#  'tourism:historic': 2,
#  'tracktype': 15,
#  'trade': 4,
#  'traffic_calming': 1,
#  'trail_visibility': 4,
#  'trailer': 1,
#  'tricycle': 1,
#  'tunnel': 380,
#  'type': 4,
#  'unsigned_ref': 52,
#  'url': 15,
#  'usage': 475,
#  'voltage': 138,
#  'wall': 17,
#  'water': 1197,
#  'waterway': 938,
#  'website': 644,
#  'website_1': 3,
#  'wheelchair': 40,
#  'wheelchair:description': 1,
#  'width': 89,
#  'wifi': 3,
#  'wikipedia': 122,
#  'wikipedia_1': 1,
#  'wood': 40,
#  'y': 1,
#  'yelp': 1}

# %%
def relation_tag_type(filename):
    rel_tags = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if element.tag == "relation":
            for child in element:
                if child.tag == "tag":
                    tag = child.attrib["k"]
                    rel_tags[tag] += 1
    return rel_tags

rel_tags = relation_tag_type('cincinnati_ohio.osm')
print "Number of distinct relation tags: ", len(rel_tags)
pprint.pprint(dict(rel_tags))

#from collections import Counter
#pprint.pprint(dict(Counter(rel_tags).most_common(25)))
# Out:
# Number of distinct relation tags:  428
# {'FIXME': 11,
#  'ISO3166-1': 1,
#  'ISO3166-1:alpha2': 1,
#  'ISO3166-1:alpha3': 1,
#  'ISO3166-1:numeric': 1,
#  'ISO3166-2': 3,
#  'NHS': 1,
#  'access': 5,
#  'addr:city': 15,
#  'addr:country': 6,
#  'addr:housenumber': 13,
#  'addr:postcode': 14,
#  'addr:state': 12,
#  'addr:street': 13,
#  'admin_level': 157,
#  'alt_name': 16,
#  'alt_name:es': 1,
#  'alt_name:vi': 3,
#  'amenity': 93,
#  'area': 12,
#  'attribution': 9,
#  'boat': 2,
#  'border_type': 149,
#  'born': 1,
#  'boundary': 184,
#  'brand': 1,
#  'building': 263,
#  'building:colour': 1,
#  'building:height': 9,
#  'building:height:underground': 1,
#  'building:levels': 21,
#  'building:levels:underground': 1,
#  'building:material': 6,
#  'building:part': 1,
#  'capacity': 1,
#  'census:population': 1,
#  'colour': 21,
#  'construction': 1,
#  'created_by': 18,
#  'cycle_network': 11,
#  'denomination': 12,
#  'description': 3,
#  'destination': 1,
#  'died': 1,
#  'ele': 41,
#  'emergency': 1,
#  'etymology': 3,
#  'fee': 2,
#  'flag': 1,
#  'foot': 5,
#  'from': 1,
#  'gnis:Class': 1,
#  'gnis:County': 1,
#  'gnis:County_num': 1,
#  'gnis:ST_alpha': 1,
#  'gnis:ST_num': 1,
#  'gnis:county_id': 35,
#  'gnis:county_name': 7,
#  'gnis:created': 34,
#  'gnis:edited': 4,
#  'gnis:feature_id': 43,
#  'gnis:id': 1,
#  'gnis:import_uuid': 7,
#  'gnis:reviewed': 1,
#  'gnis:state': 3,
#  'gnis:state_id': 36,
#  'height': 3,
#  'highway': 12,
#  'historic': 5,
#  'hour_off': 1,
#  'hour_on': 1,
#  'image': 1,
#  'import_uuid': 1,
#  'is_in': 176,
#  'is_in:city': 8,
#  'is_in:country': 134,
#  'is_in:country_code': 133,
#  'is_in:county': 4,
#  'is_in:iso_3166_2': 133,
#  'is_in:state': 188,
#  'is_in:state_code': 133,
#  'land_area': 1,
#  'landuse': 23,
#  'lanes': 1,
#  'layer': 3,
#  'leisure': 21,
#  'loc_name': 8,
#  'modifier': 7,
#  'name': 527,
#  'name:ab': 1,
#  'name:ace': 1,
#  'name:af': 1,
#  'name:als': 1,
#  'name:am': 1,
#  'name:an': 1,
#  'name:ang': 1,
#  'name:ar': 11,
#  'name:arc': 2,
#  'name:arz': 1,
#  'name:as': 1,
#  'name:ast': 1,
#  'name:av': 1,
#  'name:ay': 1,
#  'name:az': 3,
#  'name:ba': 1,
#  'name:bar': 1,
#  'name:bat-smg': 1,
#  'name:bcl': 1,
#  'name:be': 3,
#  'name:be-x-old': 1,
#  'name:bg': 4,
#  'name:bi': 1,
#  'name:bm': 1,
#  'name:bn': 4,
#  'name:bo': 1,
#  'name:bpy': 11,
#  'name:br': 1,
#  'name:bs': 1,
#  'name:bxr': 1,
#  'name:ca': 1,
#  'name:cbk-zam': 1,
#  'name:cdo': 1,
#  'name:ce': 1,
#  'name:ceb': 1,
#  'name:chr': 1,
#  'name:chy': 1,
#  'name:ckb': 1,
#  'name:co': 1,
#  'name:crh': 1,
#  'name:cs': 1,
#  'name:csb': 1,
#  'name:cu': 1,
#  'name:cv': 3,
#  'name:cy': 1,
#  'name:da': 1,
#  'name:de': 1,
#  'name:diq': 2,
#  'name:dsb': 1,
#  'name:dv': 1,
#  'name:dz': 1,
#  'name:ee': 1,
#  'name:el': 4,
#  'name:eml': 1,
#  'name:en': 13,
#  'name:eo': 2,
#  'name:es': 43,
#  'name:et': 1,
#  'name:eu': 1,
#  'name:ext': 1,
#  'name:fa': 4,
#  'name:ff': 1,
#  'name:fi': 5,
#  'name:fiu-vro': 1,
#  'name:fo': 1,
#  'name:fr': 9,
#  'name:frp': 1,
#  'name:frr': 1,
#  'name:fur': 1,
#  'name:fy': 1,
#  'name:ga': 1,
#  'name:gag': 1,
#  'name:gan': 1,
#  'name:gd': 1,
#  'name:gl': 1,
#  'name:glk': 1,
#  'name:gn': 1,
#  'name:gu': 1,
#  'name:gv': 1,
#  'name:ha': 1,
#  'name:hak': 4,
#  'name:haw': 4,
#  'name:he': 4,
#  'name:hi': 2,
#  'name:hif': 1,
#  'name:hr': 1,
#  'name:hsb': 1,
#  'name:ht': 3,
#  'name:hu': 2,
#  'name:hy': 4,
#  'name:i-mingo': 1,
#  'name:ia': 1,
#  'name:id': 1,
#  'name:ie': 1,
#  'name:ig': 1,
#  'name:ik': 1,
#  'name:ilo': 1,
#  'name:io': 1,
#  'name:is': 1,
#  'name:it': 9,
#  'name:iu': 1,
#  'name:ja': 6,
#  'name:jbo': 1,
#  'name:jv': 1,
#  'name:ka': 4,
#  'name:kaa': 1,
#  'name:kab': 1,
#  'name:kbd': 1,
#  'name:ki': 1,
#  'name:kk': 1,
#  'name:kl': 1,
#  'name:km': 1,
#  'name:kn': 1,
#  'name:ko': 4,
#  'name:koi': 1,
#  'name:krc': 1,
#  'name:ks': 1,
#  'name:ksh': 1,
#  'name:ku': 1,
#  'name:kv': 1,
#  'name:kw': 1,
#  'name:ky': 1,
#  'name:la': 2,
#  'name:lad': 1,
#  'name:lb': 1,
#  'name:lbe': 1,
#  'name:lez': 1,
#  'name:lg': 1,
#  'name:li': 1,
#  'name:lij': 2,
#  'name:lit': 1,
#  'name:lmo': 1,
#  'name:ln': 1,
#  'name:lo': 1,
#  'name:lt': 5,
#  'name:ltg': 1,
#  'name:lv': 3,
#  'name:map-bms': 1,
#  'name:mdf': 1,
#  'name:mg': 1,
#  'name:mhr': 1,
#  'name:mi': 1,
#  'name:min': 1,
#  'name:mk': 2,
#  'name:ml': 4,
#  'name:mn': 4,
#  'name:mr': 4,
#  'name:mrj': 1,
#  'name:ms': 1,
#  'name:mt': 1,
#  'name:mwl': 1,
#  'name:my': 1,
#  'name:myv': 1,
#  'name:mzn': 1,
#  'name:na': 1,
#  'name:nah': 1,
#  'name:nap': 1,
#  'name:nds': 1,
#  'name:nds-nl': 1,
#  'name:ne': 1,
#  'name:new': 1,
#  'name:nl': 1,
#  'name:nn': 1,
#  'name:no': 1,
#  'name:nov': 1,
#  'name:nrm': 1,
#  'name:nso': 1,
#  'name:nv': 2,
#  'name:oc': 1,
#  'name:om': 1,
#  'name:or': 1,
#  'name:os': 3,
#  'name:pa': 1,
#  'name:pag': 1,
#  'name:pam': 1,
#  'name:pap': 1,
#  'name:pcd': 1,
#  'name:pdc': 1,
#  'name:pfl': 1,
#  'name:pih': 1,
#  'name:pl': 7,
#  'name:pms': 2,
#  'name:pnb': 1,
#  'name:ps': 1,
#  'name:pt': 9,
#  'name:qu': 2,
#  'name:rm': 1,
#  'name:rn': 1,
#  'name:ro': 1,
#  'name:roa-tara': 1,
#  'name:ru': 5,
#  'name:rue': 1,
#  'name:rw': 1,
#  'name:sa': 1,
#  'name:sah': 1,
#  'name:sc': 1,
#  'name:scn': 1,
#  'name:sco': 1,
#  'name:sd': 1,
#  'name:se': 1,
#  'name:see': 1,
#  'name:sg': 1,
#  'name:sh': 1,
#  'name:si': 1,
#  'name:simple': 1,
#  'name:sk': 1,
#  'name:sl': 1,
#  'name:sm': 1,
#  'name:sn': 1,
#  'name:so': 1,
#  'name:sq': 1,
#  'name:sr': 4,
#  'name:srn': 1,
#  'name:ss': 1,
#  'name:stq': 1,
#  'name:su': 1,
#  'name:sv': 1,
#  'name:sw': 1,
#  'name:szl': 1,
#  'name:ta': 4,
#  'name:te': 2,
#  'name:tet': 1,
#  'name:tg': 1,
#  'name:th': 4,
#  'name:tk': 1,
#  'name:tl': 2,
#  'name:tn': 1,
#  'name:to': 1,
#  'name:tpi': 1,
#  'name:tr': 1,
#  'name:ts': 1,
#  'name:tt': 1,
#  'name:tw': 1,
#  'name:ty': 1,
#  'name:tzl': 1,
#  'name:udm': 1,
#  'name:ug': 3,
#  'name:uk': 4,
#  'name:ur': 4,
#  'name:uz': 3,
#  'name:vec': 1,
#  'name:vep': 1,
#  'name:vi': 45,
#  'name:vls': 1,
#  'name:vo': 1,
#  'name:wa': 1,
#  'name:war': 1,
#  'name:wo': 1,
#  'name:wuu': 1,
#  'name:xal': 1,
#  'name:xh': 1,
#  'name:xmf': 1,
#  'name:yi': 4,
#  'name:yo': 1,
#  'name:yue': 1,
#  'name:za': 1,
#  'name:zea': 1,
#  'name:zh': 13,
#  'name:zh-classical': 1,
#  'name:zh-min-nan': 1,
#  'name:zh-yue': 1,
#  'name:zu': 1,
#  'natural': 99,
#  'network': 225,
#  'nist:fips_code': 11,
#  'nist:state_fips': 11,
#  'note': 7,
#  'odbl': 1,
#  'office': 1,
#  'official_name': 5,
#  'official_name:vi': 1,
#  'old_etymology': 1,
#  'old_name': 33,
#  'old_name:es': 1,
#  'old_name:vi': 2,
#  'old_ref': 1,
#  'opening_hours': 1,
#  'operator': 128,
#  'osmc:symbol': 4,
#  'park:type': 2,
#  'park_ride': 1,
#  'parking': 6,
#  'passenger': 1,
#  'phone': 4,
#  'place': 140,
#  'population': 5,
#  'population:date': 1,
#  'public_transport:version': 1,
#  'railway': 1,
#  'ref': 210,
#  'ref:fips': 3,
#  'religion': 18,
#  'restriction': 109,
#  'roof:colour': 1,
#  'roof:levels': 1,
#  'roof:material': 4,
#  'roof:orientation': 1,
#  'roof:shape': 1,
#  'route': 242,
#  'service': 1,
#  'ship': 1,
#  'short_name': 2,
#  'short_name:vi': 1,
#  'site': 1,
#  'social_facility': 1,
#  'social_facility:for': 1,
#  'source': 157,
#  'source:ref': 1,
#  'sport': 10,
#  'state': 3,
#  'state_id': 16,
#  'supervised': 1,
#  'surface': 2,
#  'symbol': 30,
#  'tiger:CLASSFP': 132,
#  'tiger:CPI': 132,
#  'tiger:FUNCSTAT': 132,
#  'tiger:LSAD': 132,
#  'tiger:MTFCC': 132,
#  'tiger:NAME': 132,
#  'tiger:NAMELSAD': 132,
#  'tiger:PCICBSA': 132,
#  'tiger:PCINECTA': 132,
#  'tiger:PLACEFP': 132,
#  'tiger:PLACENS': 132,
#  'tiger:PLCIDFP': 132,
#  'tiger:STATEFP': 132,
#  'timezone': 1,
#  'to': 1,
#  'tourism': 5,
#  'type': 1158,
#  'unsigned_ref': 4,
#  'url': 14,
#  'water': 12,
#  'waterway': 5,
#  'website': 73,
#  'wheelchair': 15,
#  'wikidata': 6,
#  'wikipedia': 232}

# %% [markdown]
# ### users.py

# %%
import xml.etree.cElementTree as ET
import pprint
from collections import defaultdict

def get_user(element):
    return element.attrib["uid"]

def process_map(filename):
    users = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if element.tag == "node" or element.tag == "way":
            user = get_user(element)
            users[user] += 1
    return users


users = process_map('cincinnati_ohio.osm')
user_count = len(users)
print "Number of distinct users: ", user_count
pprint.pprint(dict(users))
# Out:
# Number of distinct users:  565
# {'1007528': 6,
#  '1012362': 444,
#  '103253': 8,
#  '1047195': 17,
#  '104962': 27,
#  '1051550': 34,
#  '105946': 3,
#  '10786': 18,
#  '1081635': 46,
#  '1087647': 2,
#  '108781': 772,
#  '1096567': 2,
#  '109661': 117,
#  '110263': 1,
#  '1108251': 237463,
#  '11126': 1,
#  '1126944': 81,
#  '1149057': 17,
#  '115918': 1,
#  '118021': 6,
#  '118856': 1,
#  '1195104': 8,
#  '1198074': 4,
#  '119881': 4,
#  '120146': 11835,
#  '1203657': 1,
#  '120468': 69,
#  '1205642': 8,
#  '1207672': 2643,
#  '1209932': 204,
#  '121241': 1144,
#  '1214881': 44,
#  '1215563': 58,
#  '1219059': 432,
#  '1219875': 5,
#  '1224467': 1,
#  '123537': 4,
#  '1236137': 4,
#  '1240849': 140,
#  '12434': 2,
#  '1246157': 3,
#  '1250514': 1,
#  '1260280': 18,
#  '1261813': 4,
#  '128017': 22,
#  '129255': 2,
#  '130065': 5,
#  '130472': 42,
#  '1306': 10,
#  '131059': 16,
#  '1329572': 18,
#  '1330847': 4,
#  '135163': 7,
#  '1352438': 7,
#  '1376118': 2,
#  '137673': 1,
#  '13832': 10,
#  '13834': 97,
#  '1408522': 22,
#  '1410107': 5,
#  '1436654': 1,
#  '1436909': 16,
#  '14390': 9,
#  '1442206': 2,
#  '1443767': 1,
#  '145231': 102,
#  '147510': 344876,
#  '14850': 8,
#  '1486839': 8,
#  '1494110': 134,
#  '1497709': 133,
#  '150272': 56,
#  '150680': 1,
#  '152074': 22,
#  '152289': 9,
#  '1535212': 36,
#  '153669': 2,
#  '1548224': 3,
#  '1554107': 1,
#  '156599': 2,
#  '156977': 94,
#  '158204': 1,
#  '158694': 3,
#  '158718': 2,
#  '159651': 2,
#  '159655': 2,
#  '160494': 375,
#  '160651': 106,
#  '160949': 60,
#  '1617449': 1,
#  '161951': 1,
#  '163290': 5,
#  '16330': 1,
#  '163973': 4,
#  '165061': 3,
#  '165064': 18,
#  '1653950': 10,
#  '165869': 2,
#  '16591': 10,
#  '165931': 103,
#  '166129': 8,
#  '166378': 4,
#  '16669': 3,
#  '167009': 26,
#  '1679': 125,
#  '1679807': 81,
#  '168517': 2,
#  '169004': 48,
#  '170106': 3,
#  '170900': 1,
#  '1710954': 59,
#  '1714220': 78,
#  '172061': 9,
#  '1722930': 1,
#  '172631': 6,
#  '1728981': 21,
#  '1731974': 11,
#  '173918': 1,
#  '1739350': 6,
#  '1745406': 253,
#  '1748585': 9,
#  '175667': 1,
#  '1759469': 30,
#  '1772211': 10,
#  '1774334': 12,
#  '1774578': 6,
#  '1774581': 45,
#  '1774753': 5,
#  '1775434': 11,
#  '1775444': 4,
#  '178186': 62,
#  '1782960': 3,
#  '1783785': 2,
#  '17857': 14,
#  '1786023': 3,
#  '1786024': 6,
#  '179080': 103,
#  '1792644': 8,
#  '1802220': 112,
#  '18069': 20,
#  '181135': 10,
#  '1813535': 614469,
#  '1829683': 335,
#  '1830209': 2,
#  '1832883': 3,
#  '1845844': 1,
#  '18480': 3650,
#  '186057': 12,
#  '186195': 71,
#  '1867873': 2,
#  '1868637': 1413,
#  '1868837': 1,
#  '1869152': 8,
#  '1871122': 7,
#  '1871247': 28,
#  '1873298': 2,
#  '1881064': 5,
#  '1882950': 10,
#  '1888437': 1,
#  '1901542': 10,
#  '1908700': 1,
#  '1911765': 2,
#  '1914808': 23,
#  '19239': 1,
#  '192829': 5,
#  '1929182': 1,
#  '194751': 4,
#  '1954172': 2,
#  '1960922': 1,
#  '1960971': 10499,
#  '1962477': 4,
#  '1962706': 5,
#  '1963525': 3,
#  '1963825': 10,
#  '1972209': 12044,
#  '1977838': 31,
#  '1985322': 5,
#  '198585': 6271,
#  '1986363': 13,
#  '199396': 103,
#  '1996396': 3,
#  '200922': 3,
#  '2010647': 1,
#  '2010831': 1,
#  '2010833': 21,
#  '2010842': 1,
#  '2012449': 18,
#  '201359': 3,
#  '2015820': 728,
#  '2017094': 3,
#  '2017202': 11,
#  '2017210': 7,
#  '2017301': 3,
#  '2017314': 178,
#  '2025202': 17,
#  '2027890': 3,
#  '2029175': 1,
#  '2029203': 12,
#  '2029219': 60,
#  '2034630': 59,
#  '2041119': 5,
#  '2042796': 1,
#  '204361': 52,
#  '2046831': 12,
#  '2047853': 1,
#  '204929': 10,
#  '2055052': 14,
#  '205523': 31,
#  '2060619': 2089,
#  '2061006': 3,
#  '2063187': 133,
#  '2065004': 1,
#  '2075078': 4,
#  '207581': 37,
#  '207745': 2328,
#  '2082405': 12,
#  '2082454': 711,
#  '2082790': 11,
#  '2084511': 41,
#  '2086803': 61,
#  '2089002': 45,
#  '210260': 4,
#  '2106198': 7,
#  '2115749': 38,
#  '2118267': 9,
#  '2118269': 1,
#  '212111': 1,
#  '2125961': 2,
#  '213831': 1,
#  '214969': 3,
#  '2152417': 3,
#  '2170028': 3,
#  '2173348': 9,
#  '219591': 117,
#  '2197750': 997,
#  '2200116': 247,
#  '2210050': 26,
#  '22122': 195,
#  '2219338': 508,
#  '2226712': 690,
#  '223675': 450,
#  '2245537': 26,
#  '2252765': 6,
#  '2252860': 60,
#  '2257281': 15,
#  '2264589': 1,
#  '2283575': 4,
#  '229129': 3,
#  '2291431': 418,
#  '2292096': 1,
#  '232126': 19,
#  '2361195': 2,
#  '236412': 135,
#  '2369262': 17,
#  '2377377': 258,
#  '2382273': 1,
#  '23878': 1,
#  '2398787': 1,
#  '2406578': 6,
#  '2422476': 2,
#  '24247': 3,
#  '243003': 136,
#  '2435185': 10,
#  '2436843': 32,
#  '2436868': 53,
#  '2438959': 2,
#  '2443901': 8,
#  '2443909': 9,
#  '244562': 91,
#  '2448607': 1,
#  '2456601': 2,
#  '2476223': 51,
#  '24807': 5173,
#  '248960': 2,
#  '2497300': 27,
#  '2498752': 68,
#  '2506686': 1,
#  '2511706': 209,
#  '2512300': 2732,
#  '2514633': 1857,
#  '251543': 4,
#  '2527838': 81,
#  '252811': 713,
#  '2545951': 5,
#  '25508': 124,
#  '2554698': 112,
#  '2576585': 79,
#  '2585958': 693,
#  '25867': 7,
#  '2595539': 1,
#  '2607048': 1146,
#  '2612': 2,
#  '262151': 10,
#  '26299': 80,
#  '26348': 3,
#  '2644101': 30,
#  '2648244': 1,
#  '2652392': 1,
#  '2669671': 59,
#  '2677299': 187,
#  '2678290': 186,
#  '2679756': 3781,
#  '2680': 6,
#  '2689188': 3,
#  '271137': 44,
#  '2748195': 185,
#  '2748755': 2,
#  '2754027': 7,
#  '2756193': 11,
#  '2758': 8,
#  '2768148': 8,
#  '2774398': 9,
#  '2782045': 1,
#  '27908': 749,
#  '28145': 99,
#  '2820500': 6,
#  '2823295': 44,
#  '28269': 1,
#  '2844346': 15,
#  '2847988': 19,
#  '2854645': 57,
#  '28559': 1,
#  '2856392': 7,
#  '2859402': 2,
#  '2876975': 9,
#  '28775': 2,
#  '28783': 107,
#  '288498': 18,
#  '28852': 599,
#  '2905914': 11,
#  '290680': 8,
#  '29084': 1,
#  '29125': 5,
#  '292007': 2,
#  '292391': 17,
#  '292665': 1193,
#  '2929338': 2,
#  '2944689': 88,
#  '2962062': 102,
#  '296480': 15,
#  '296700': 7,
#  '296790': 3,
#  '2975766': 307,
#  '2983637': 10,
#  '299327': 27,
#  '3014197': 1,
#  '3019482': 1,
#  '3022157': 1,
#  '3052144': 7,
#  '3052556': 3,
#  '305985': 62,
#  '3079340': 6,
#  '308181': 3,
#  '3093671': 6,
#  '3110870': 2,
#  '3116565': 5076,
#  '31231': 4,
#  '312894': 66,
#  '3134309': 270,
#  '3134383': 12,
#  '3154182': 1591,
#  '3158': 34,
#  '3161278': 101,
#  '316694': 8,
#  '3167213': 1,
#  '3183351': 1,
#  '32169': 2,
#  '322785': 13,
#  '323054': 36,
#  '3232074': 8,
#  '329453': 2,
#  '32952': 16,
#  '3302935': 44,
#  '3309624': 73,
#  '331548': 5,
#  '336460': 13,
#  '336659': 29,
#  '33757': 899093,
#  '33773': 13,
#  '340075': 3722,
#  '349027': 147,
#  '34927': 9,
#  '3516': 4,
#  '352368': 2,
#  '35243': 6,
#  '355242': 7,
#  '3560': 6,
#  '3582': 378,
#  '360392': 1644,
#  '36121': 11,
#  '361746': 7,
#  '364143': 2,
#  '368215': 1,
#  '37137': 2,
#  '373434': 19,
#  '37548': 70,
#  '381253': 10211,
#  '381349': 210,
#  '381942': 4,
#  '38487': 16,
#  '38588': 1,
#  '389806': 6,
#  '390669': 1,
#  '393740': 125,
#  '39457': 1,
#  '39504': 1,
#  '396743': 4,
#  '39688': 1,
#  '398086': 2,
#  '398883': 2,
#  '401490': 14,
#  '402624': 29,
#  '40310': 82,
#  '411783': 1,
#  '414318': 793,
#  '42123': 16,
#  '42918': 2,
#  '436419': 9,
#  '437598': 119,
#  '44312': 1,
#  '4467': 3,
#  '447903': 8,
#  '45027': 35,
#  '451048': 13,
#  '451693': 13464,
#  '454589': 8,
#  '45720': 1,
#  '4697': 16,
#  '470089': 1,
#  '4732': 508,
#  '473471': 25,
#  '47544': 54,
#  '475877': 43,
#  '47647': 12134,
#  '479256': 1,
#  '480686': 3,
#  '481380': 2,
#  '484401': 541,
#  '492311': 1,
#  '49351': 1,
#  '4951': 270,
#  '498214': 2,
#  '499848': 1,
#  '50624': 8,
#  '51045': 368,
#  '510836': 59,
#  '520239': 3,
#  '5211': 1,
#  '521684': 3,
#  '523643': 4,
#  '527506': 105,
#  '527535': 9,
#  '52797': 2,
#  '528465': 2,
#  '529645': 2,
#  '53127': 8,
#  '533465': 1,
#  '5359': 13,
#  '537835': 13,
#  '542095': 1,
#  '5453': 301,
#  '54759': 1,
#  '554234': 30,
#  '555271': 6,
#  '558778': 8,
#  '55916': 10,
#  '564222': 13,
#  '567139': 159,
#  '567792': 13,
#  '571426': 2,
#  '57158': 31,
#  '5748': 3,
#  '575934': 1,
#  '576100': 1,
#  '576861': 64,
#  '578519': 50,
#  '579545': 2,
#  '58013': 27,
#  '582841': 9,
#  '589596': 6,
#  '592279': 1,
#  '592819': 40,
#  '593205': 7,
#  '595221': 4,
#  '596047': 13,
#  '597064': 5,
#  '597941': 14,
#  '599436': 5,
#  '600612': 1,
#  '60244': 1,
#  '608121': 1,
#  '614305': 1,
#  '618166': 181,
#  '618377': 16,
#  '618879': 10,
#  '61891': 1,
#  '620257': 9,
#  '629623': 4,
#  '635080': 1,
#  '638935': 5,
#  '643738': 77,
#  '645457': 9,
#  '65148': 1,
#  '652333': 3,
#  '656832': 9,
#  '663559': 4,
#  '66670': 24,
#  '668889': 2,
#  '675965': 8282,
#  '67862': 5,
#  '68842': 2,
#  '68982': 10,
#  '6975': 5,
#  '697694': 1,
#  '699357': 84,
#  '700576': 1,
#  '701297': 6,
#  '703517': 54,
#  '7050': 18,
#  '70696': 29,
#  '711190': 102,
#  '7168': 1078,
#  '718617': 7,
#  '722137': 214,
#  '727134': 31,
#  '72844': 5881,
#  '73072': 26,
#  '7412': 13,
#  '7437': 1,
#  '74937': 6,
#  '76002': 2,
#  '771165': 35,
#  '775666': 7,
#  '78656': 9,
#  '80285': 3,
#  '804478': 429,
#  '82317': 7,
#  '8339': 2,
#  '837066': 2,
#  '83725': 346,
#  '83905': 75,
#  '84054': 89,
#  '84681': 1,
#  '85673': 139,
#  '8609': 2,
#  '8703': 74,
#  '875791': 4,
#  '8764': 51,
#  '88164': 55,
#  '88746': 1,
#  '88961': 2,
#  '8909': 6,
#  '91126': 45,
#  '91568': 2,
#  '92274': 1,
#  '92286': 15,
#  '93679': 15,
#  '94578': 93,
#  '950776': 45,
#  '957': 1,
#  '9607': 2,
#  '96974': 8,
#  '971533': 3,
#  '99365': 12,
#  '996997': 5}

# %% [markdown]
# ### tags.py

# %%
import xml.etree.cElementTree as ET
import pprint
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


# check the "k" value for each "<tag>" and see if they can be 
# valid keys in MongoDB, as well as see if there are any other 
# potential problems.
def key_type(element, keys):
    if element.tag == "tag":
        k_value = element.attrib['k']
        if lower.search(k_value):
            keys["lower"] += 1
        elif lower_colon.search(k_value):
            keys["lower_colon"] += 1
        elif problemchars.search(k_value):
            keys["problemchars"] += 1
        else:
            keys["other"] += 1        
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys


keys = process_map('cincinnati_ohio.osm')
pprint.pprint(keys)
# Out:
# {'lower': 458445, 'lower_colon': 294301, 'other': 12373, 'problemchars': 0}

# %% [markdown]
# ### audit.py

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "cincinnati_ohio.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
# matches strings at the end ($)
# s.t. the position is at a word boundary (\b),
# does not includ whitespace chars (\S),
# and there may or may not be a '.' at the end


expected_st_types = ["Alley", "Avenue", "Boulevard", "Circle", "Court", "Drive",
            "Lane", "Pike", "Parkway", "Place", "Point", "Road", "Run",
            "Street", "Terrace", "Trail", "Way"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected_st_types:
            street_types[street_type].add(street_name)


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    street_names = defaultdict(int)
    states = defaultdict(int)
    postcodes = defaultdict(int)
    cities = defaultdict(int)
    
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if tag.attrib['k'] == "addr:street":
                    audit_street_type(street_types, tag.attrib['v'])
                    name = tag.attrib['v']
                    street_names[name] += 1
                    
                if tag.attrib['k'] == "addr:state":
                    state = tag.attrib['v']
                    states[state] += 1
                    
                if tag.attrib['k'] == "addr:postcode":
                    postcode = tag.attrib['v']
                    postcodes[postcode] += 1
                
                if tag.attrib['k'] == "addr:city":
                    city = tag.attrib['v']
                    cities[city] += 1
                    
    return street_types, street_names, states, postcodes, cities


st_types, st_names, states, postcodes, cities = audit(OSMFILE)

# %%
pprint.pprint(dict(st_types))
pprint.pprint(dict(st_names))
# Out:
# {'276': set(['State Route 276']),
#  '28': set(['Old State Route 28', 'State Route 28']),
#  '3': set(['West United States Highway 22 and 3']),
#  '42': set(['Route 42', 'State Route 42', 'U.S. Highway 42']),
#  '48': set(['Ohio 48']),
#  '50': set(['US 50']),
#  '63': set(['State Route 63']),
#  'A': set(['US HWY  42 #A']),
#  'Ashley': set(['Ashley']),
#  'Ave': set(['Kenard Ave', 'W Clifton Ave', 'Whetsel Ave']),
#  'Avene': set(['Ludlow Avene']),
#  'Avnue': set(['South Fort Thomas Avnue']),
#  'Bend': set(['River Bend']),
#  'Birch': set(['Birch']),
#  'Breezes': set(['Soaring Breezes']),
#  'Cove': set(['Timber Cove']),
#  'Crest': set(['Fairway Crest']),
#  'Crossing': set(['Courtyard Crossing', 'North Bend Crossing']),
#  'Dr': set(['Beckett Center Dr',
#             'Cincinnati Mills Dr',
#             'Clough Woods Dr',
#             'Genntown Dr']),
#  'Edge': set(['Waters Edge']),
#  'Farm': set(['Stonebridge Farm']),
#  'Highway': set(['Dixie Highway']),
#  'Hill': set(['Liberty Hill']),
#  'Hollow': set(['Windy Hollow']),
#  'Pass': set(['Woodsong Pass']),
#  'Plaza': set(['Procter & Gamble Plaza']),
#  'Rd': set(['Bridgetown Rd', 'Princeton Rd']),
#  'Rd.': set(['Montgomery Rd.']),
#  'Ridgetop': set(['Ridgetop']),
#  'Row': set(['Masters Row']),
#  'St': set(['215 Calhoun St',
#             'Chickasaw St',
#             'Clark St',
#             'Greenup St',
#             'Vine St']),
#  'State': set(['Ritchie State']),
#  'Trace': set(['Shenandoah Trace']),
#  'Turn': set(['Traditions Turn']),
#  'US-50': set(['US-50']),
#  'Warner': set(['Warner']),
#  'avenue': set(['Hamilton avenue']),
#  'dr.': set(['Kemper Meadow dr.']),
#  'meadow': set(['Kemper meadow']),
#  'street': set(['vine street']),
#  'ter': set(['firshade ter'])}
# {'215 Calhoun St': 1,
#  'Albert Sabin Way': 2,
#  'Albright Drive': 38,
#  'Alexandria Pike': 2,
#  'Allegro Court': 11,
#  'Allen Road': 1,
#  'Amsterdam Road': 2,
#  'Anderson Way': 1,
#  'Anna Street': 1,
#  'Antietam Drive': 16,
#  'Apache Court': 6,
#  'Apgar Drive': 15,
#  'Appaloosa Drive': 1,
#  'Appomattox Court': 5,
#  'Aquarium Way': 1,
#  'Arbor Square Drive': 2,
#  'Arcaro Drive': 8,
#  'Arnold Lane': 21,
#  'Arnold Palmer Drive': 13,
#  'Asbury Avenue': 4,
#  'Ashley': 2,
#  'Augusta Boulevard': 27,
#  'Babygold Court': 1,
#  'Bares Creek Court': 12,
#  'Barret Road': 1,
#  'Baxter Road': 1,
#  'Bay Court': 5,
#  'Beaver Road': 1,
#  'Beckett Center Dr': 2,
#  'Beckett Park Drive': 1,
#  'Beech Hill Avenue': 1,
#  'Beech Road': 4,
#  'Beechmont Avenue': 2,
#  'Bellwood Drive': 55,
#  'Belmont Court': 8,
#  'Bent Creek Drive': 35,
#  'Bentley Pass Lane': 19,
#  'Birch': 2,
#  'Bird Dog Court': 7,
#  'Black Horse Run': 22,
#  'Blue Rock Street': 1,
#  'Bold Forbes Road': 11,
#  'Bond Place': 1,
#  'Bond Road': 1,
#  u'Branch Hill\u2013Guinea Pike': 28,
#  u'Branch Hill\u2013Loveland Road': 87,
#  u'Branch Hill\u2013Miamiville Road': 1,
#  'Brandenburg Drive': 26,
#  'Braodway Street': 3,
#  'Brecker Street': 7,
#  'Brentmoor Drive': 23,
#  'Brentmoor Lane': 2,
#  'Bridge Lane': 1,
#  'Bridge Street': 1,
#  'Bridgetown Rd': 1,
#  'Bridgetown Road': 2,
#  'Brigadoon Drive': 1,
#  'Bristol Court': 10,
#  'Broadway Street': 22,
#  'Brookbridge Drive': 1,
#  'Brookdale Court': 1,
#  'Brooklyn Drive': 3,
#  'Brushwood Drive': 22,
#  'Buckwheat Road': 1,
#  'Bullittsburg Church Road': 1,
#  'Burlington Pike': 1,
#  'Buttermilk Pike': 6,
#  'Cactus Lane': 27,
#  'Calhoun Street': 1,
#  'Camp Ernst Road': 3,
#  'Campus Way': 1,
#  'Candlewood Court': 4,
#  'Cannonade Drive': 35,
#  'Capitol Avenue': 10,
#  'Cardinal Court': 5,
#  'Carolina Trace Road': 1,
#  'Carothers Road': 3,
#  'Carriage Hill Lane': 5,
#  'Carrousel Court': 14,
#  'Carter Grove Lane': 12,
#  'Castle Drive': 29,
#  'Castleberry Court': 1,
#  'Cedar Drive': 47,
#  'Cedar Road': 8,
#  'Centennial Circle': 1,
#  'Center Street': 1,
#  'Central Avenue': 4,
#  'Centurion Drive': 53,
#  'Chalfonte Place': 1,
#  'Chamber Drive': 5,
#  'Chatham Woods Drive': 23,
#  'Cherokee Drive': 32,
#  'Chickasaw St': 1,
#  'Chickasaw Street': 2,
#  'Churchill Court': 15,
#  'Cilley Road': 1,
#  'Cincinnati Columbus Road': 1,
#  'Cincinnati Mills Dr': 1,
#  'Cinnamon Street': 6,
#  'Citation Court': 8,
#  'Clark St': 1,
#  'Clay Street': 14,
#  'Clearfield Court': 14,
#  'Clearwater Place': 4,
#  'Cleinview Avenue': 22,
#  'Cleves Avenue': 1,
#  'Cleves Warsaw Pike': 2,
#  'Clifton Avenue': 14,
#  'Clifton Hills Avenue': 1,
#  'Clock Tower Way': 1,
#  'Clough Woods Dr': 1,
#  'Cobalt Way': 16,
#  'Coke Avenue': 4,
#  'Colbourne Court': 7,
#  'Coleberry Court': 2,
#  'Coleman Drive': 1,
#  'Colerain Avenue': 3,
#  'Collins Avenue': 2,
#  'Colonial Drive': 22,
#  'Comanche Court': 9,
#  'Compton Road': 1,
#  'Conroy Street': 1,
#  'Cooper Avenue': 2,
#  'Cordero Trail': 15,
#  'Cornell Road': 3,
#  'Cottonwood Drive': 4,
#  'County Down Lane': 3,
#  'Courtyard Crossing': 7,
#  'Coventry Court': 19,
#  'Covey Court': 12,
#  'Creekside Drive': 16,
#  'Crown Point Lane': 6,
#  'Daly Road': 1,
#  'Damon Road': 1,
#  'Darbyshire Court': 3,
#  'Decatur Lane': 11,
#  'Declaration Drive': 1,
#  'Deer Trail Court': 5,
#  'Deerfield Boulevard': 4,
#  'Deerview Drive': 37,
#  'Delta Avenue': 1,
#  'Dickens Hill Drive': 4,
#  'Disney Street': 1,
#  'Dixie Highway': 8,
#  'Dogwood Drive': 31,
#  'Doll Lane': 1,
#  'Dominion Drive': 11,
#  'Donnermeyer Drive': 2,
#  'Donwiddle Drive': 32,
#  'Dorrit Drive': 2,
#  'Dressage Lane': 3,
#  'Durango Drive': 22,
#  'Eagle Creek Road': 1,
#  'Eagleview Court': 5,
#  'East 10th Street': 23,
#  'East 12th Street': 22,
#  'East 13th Street': 60,
#  'East 14th Street': 7,
#  'East 33rd Street': 1,
#  'East 4th Street': 3,
#  'East 5th Street': 4,
#  'East 6th Street': 1,
#  'East 7th Street': 1,
#  'East 8th Street': 1,
#  'East 9th Street': 3,
#  'East Business Way': 1,
#  'East Court Street': 13,
#  'East Eighth Street': 1,
#  'East Fourth Street': 1,
#  'East Gallatin Street': 1,
#  'East Kemper Road': 25,
#  'East Knollwood Circle': 43,
#  'East Main Street': 2,
#  'East McMicken Avenue': 2,
#  'East McMillan Street': 2,
#  'East Mehring Way': 1,
#  'East Second Street': 1,
#  'East Sharon Road': 7,
#  'East State Road': 2,
#  'East University Avenue': 1,
#  'Eastbury Drive': 35,
#  'Eastgate Boulevard': 2,
#  'Eastgate South Drive': 1,
#  'Eastgate Square Drive': 1,
#  'Edgefield Drive': 13,
#  'Edwards Road': 3,
#  'Elite Lane': 4,
#  'Elklick Road': 1,
#  'Elm Street': 2,
#  'Elmfield Drive': 14,
#  'Enfield Street': 1,
#  'Enyart Road': 89,
#  'Epworth Road': 29,
#  'Erie Avenue': 20,
#  'Essex Place': 1,
#  'Este Avenue': 1,
#  'Evanswood Place': 1,
#  'Evendale Drive': 1,
#  'Evensong Drive': 6,
#  'Ewing Boulevard': 2,
#  'Fairfield Avenue': 1,
#  'Fairway Crest': 35,
#  'Fairwind Court': 18,
#  'Falcon Lane': 21,
#  'Fallcreek Lane': 9,
#  'Fallenoak Court': 16,
#  'Fallswood Court': 8,
#  'Farmstead Drive': 15,
#  'Fawn Court': 7,
#  'Fawncrest Court': 14,
#  'Ferguson Road': 1,
#  'Fields Ertel Road': 27,
#  'Fieldsedge Drive': 1,
#  'Forest View Court': 8,
#  'Forsythe Place': 1,
#  'Founders Drive': 1,
#  'Foxgate Way': 29,
#  'Frogtown Connector Road': 1,
#  'Gailynn Drive': 30,
#  'Garfield Place': 1,
#  'Garrard Street': 1,
#  'Gauche Park Drive': 1,
#  'Genntown Dr': 1,
#  'Gentlewind Court': 18,
#  'Georgia Avenue': 1,
#  'Gerome Way': 16,
#  'Gilbert Avenue': 2,
#  'Glen Ellyn Drive': 3,
#  'Glen Lake Road': 72,
#  u'Glendale\u2013Milford Road': 1,
#  'Glenway Avenue': 3,
#  'Gourmet Lane': 28,
#  'Grace Avenue': 1,
#  'Grandview Avenue': 6,
#  'Grear Militzer Place': 1,
#  'Greenhedge Lane': 26,
#  'Greenup St': 1,
#  'Greenup Street': 1,
#  'Hagewa Drive': 1,
#  'Halter Lane': 2,
#  'Hamil Court': 6,
#  'Hamilton Avenue': 9,
#  'Hamilton avenue': 2,
#  'Hanfield Street': 58,
#  'Hanna Avenue': 16,
#  'Hansel Avenue': 2,
#  'Harrison Avenue': 1,
#  'Hauck Road': 2,
#  'Hawthorne Avenue': 1,
#  'Hawthorne Woods Court': 9,
#  'Hazelwood Road': 1,
#  'Heartwood Court': 6,
#  'Heather Hill Lane': 10,
#  'Heidelberg Drive': 75,
#  'Heights Boulevard': 1,
#  'Heritage Pointe Boulevard': 26,
#  'Hickory Ridge Lane': 33,
#  'High Country Lane': 1,
#  'High Street': 2,
#  'Highland Pike': 2,
#  'Highland Street': 2,
#  'Highridge Circle': 8,
#  'Hightower Court': 16,
#  'Hunterswood Lane': 15,
#  'Hunting Fields Lane': 4,
#  'Hutchinson Road': 3,
#  'Hyde Park Avenue': 1,
#  'Industrial Road': 1,
#  'Inland Lane': 8,
#  'Iroquois Drive': 22,
#  'Isabella Avenue': 1,
#  'Isabella Drive': 9,
#  'Jackson Dell Court': 1,
#  'Jacobs Court': 10,
#  'Jamestown Street': 30,
#  'Jane Court': 1,
#  'Jefferson Avenue': 1,
#  'Jenna Lane': 5,
#  'Jerome Avenue': 6,
#  'Jerry Lee Drive': 1,
#  'Jonellis Court': 2,
#  'Joseph E. Schmiade Road': 1,
#  'Karl Brown Way': 1,
#  'Kemper Grove Lane': 46,
#  'Kemper Meadow dr.': 1,
#  'Kemper meadow': 1,
#  'Kenard Ave': 1,
#  'Kennel Road': 1,
#  'Kenton Lands Road': 1,
#  'Kenwood Road': 3,
#  'Kieley Place': 1,
#  'Kilkerry Way': 1,
#  'Kingsley Drive': 1,
#  'Kleeman Lake Court': 1,
#  'Klotter Avenue': 1,
#  'Kosine Drive': 18,
#  'Lakeview Court': 20,
#  'Laurelwood Drive': 22,
#  'Lavinia Avenue': 1,
#  'Lebanon Road': 7,
#  'Legacy Lane': 11,
#  'Legend Way': 4,
#  'Lemontree Lane': 10,
#  'Levee Way': 4,
#  'Lexington Drive': 29,
#  'Liberty Hill': 10,
#  'Lila Avenue': 4,
#  'Lindale Nicholsville Road': 1,
#  'Linden Drive': 1,
#  'Lindenhall Drive': 68,
#  'Linn Street': 1,
#  'Linwood Avenue': 7,
#  'Little River Lane': 33,
#  'Locust Avenue': 1,
#  'Loveland Madeira Road': 1,
#  'Loveland Trace Court': 15,
#  u'Loveland\u2013Madeira Road': 10,
#  u'Loveland\u2013Miamiville Road': 40,
#  'Lowell Avenue': 1,
#  'Lower River Road': 6,
#  'Ludlow Avene': 2,
#  'Ludlow Avenue': 13,
#  'Ludlow Street': 1,
#  'Lycoming Street': 11,
#  'Madison Avenue': 4,
#  'Madison Pike': 1,
#  'Madison Road': 48,
#  'Main Street': 107,
#  'Mall Road': 3,
#  'Manor Lane': 2,
#  'Maple Drive': 6,
#  'Maple Street': 1,
#  'Martha Layne Collins Boulevard': 2,
#  'Masters Row': 11,
#  'Matson Place': 2,
#  'Mattec Drive': 1,
#  'McFarland Street': 3,
#  'McKinney Road': 39,
#  'McMillan Avenue': 3,
#  'McMillan Street': 1,
#  'McPicken Drive': 1,
#  'Meadowknoll Drive': 54,
#  'Meadview Place': 2,
#  'Meijer Drive': 3,
#  'Mellow Wood Lane': 7,
#  'Melodymanor Drive': 2,
#  'Memorial Parkway': 2,
#  'Mercedes Drive': 1,
#  'Mercy Health Boulevard': 1,
#  'Miami Avenue': 1,
#  'Miami Buff Court': 9,
#  'Miami Court': 8,
#  'Miami Heights Court': 21,
#  'Miami Lake Drive': 29,
#  'Miami Trace Court': 14,
#  'Miami Trails Drive': 64,
#  'Miami Woods Drive': 49,
#  'Miamicrest Drive': 21,
#  'Miamiridge Drive': 63,
#  'Miamiview Court': 21,
#  'Michigan Avenue': 17,
#  'Midpines Drive': 1,
#  'Millbrook Lane': 22,
#  'Millstone Court': 21,
#  'Mission Court': 16,
#  'Mohican Drive': 22,
#  'Monroe Street': 14,
#  'Montana Avenue': 1,
#  'Montegor Drive': 1,
#  'Montgomery Rd.': 1,
#  'Montgomery Road': 12,
#  'Morgans Run Road': 3,
#  'Mossy Glen Drive': 10,
#  'Mount Adams Circle': 1,
#  'Mount Zion Road': 2,
#  'Muirfield Drive': 1,
#  'Mulberry Road': 3,
#  'Mulhauser Road': 3,
#  'Murle Lane': 37,
#  'Natorp Boulevard': 2,
#  'Nature Park Drive': 1,
#  'Navaho Drive': 45,
#  'Neale Lane': 28,
#  'Newbridge Drive': 1,
#  'Nimrod Boulevard': 16,
#  'Ninth Street': 1,
#  'North 3rd Street': 1,
#  'North Bend Crossing': 1,
#  'North Bend Road': 7,
#  'North Lebanon Road': 27,
#  'North Miami Avenue': 3,
#  'North Orient Street': 1,
#  'North Pine Island Road': 1,
#  'Oak Bark Road': 13,
#  'Oak Canyon Drive': 31,
#  'Oak Dale Lane': 1,
#  'Oak Drive': 6,
#  'Oak Leaf Lane': 1,
#  'Oak Ridge Court': 13,
#  'Oakland Drive': 4,
#  'Oakland Road': 17,
#  'Oakvalley Court': 14,
#  'Oasis Drive': 27,
#  'Oasis Pointe Drive': 7,
#  'Observatory Avenue': 17,
#  'Observatory Place': 1,
#  'Ohio 48': 3,
#  'Ohio Avenue': 2,
#  'Old Bank Road': 2,
#  'Old Stable Road': 6,
#  'Old State Route 28': 8,
#  'Old Taylor Mill Road': 8,
#  'Oneida Drive': 17,
#  'Orchard Street': 3,
#  'Osage Drive': 4,
#  'Overlook Drive': 12,
#  u'O\u2019Bannonville Road': 15,
#  'Palmer Place': 16,
#  'Park Court': 9,
#  'Parkway Drive': 1,
#  'Pavillion Parkway': 1,
#  'Paxton Road': 26,
#  'Perry Street': 2,
#  'Pershing Avenue': 19,
#  'Pewter Court': 5,
#  'Pheasant Hills Drive': 29,
#  'Pheasant Lake Drive': 16,
#  'Pheasant Woods Court': 7,
#  'Pincay Court': 9,
#  'Pine Cove Lane': 14,
#  'Pinewood Drive': 17,
#  'Pintail Drive': 30,
#  'Plainfield Road': 2,
#  'Plantation Pointe Drive': 15,
#  'Pleasant Valley Court': 10,
#  'Pleasant Valley Road': 1,
#  'Plum Street': 4,
#  'Poplar Drive': 46,
#  'Potomac Court': 7,
#  'Preakness Lane': 3,
#  'Price Avenue': 2,
#  'Princeton Rd': 1,
#  'Procter & Gamble Plaza': 2,
#  'Pueblo Drive': 5,
#  'Putz Place': 1,
#  'Quail Run Court': 12,
#  'Quailwoods Drive': 53,
#  'Queensway Drive': 22,
#  'Race Street': 13,
#  'Raes Creek Court': 14,
#  'Ramsey Court': 23,
#  'Ravinewood Terrace': 5,
#  'Reading Road': 16,
#  'Red Roan Drive': 10,
#  'Redbud Court': 5,
#  'Redhawk Court': 9,
#  'Retswood Drive': 20,
#  'Retview Lane': 19,
#  'Rich Road': 41,
#  'Richland Park Drive': 17,
#  'Ridge Road': 1,
#  'Ridgetop': 5,
#  'Ridgeview Court': 12,
#  'Ridgewood Drive': 51,
#  'Ritchie State': 1,
#  'Riva Ridge Court': 18,
#  'River Bend': 5,
#  'River Valley Road': 1,
#  'Riveroaks Drive': 30,
#  'Riverside Drive': 2,
#  'Riverwalk Lane': 17,
#  u'River\u2019s Edge Drive': 1,
#  'Riviera Drive': 2,
#  'Robin Avenue': 1,
#  'Rohs Street': 39,
#  'Rollins Drive': 20,
#  'Romar Drive': 3,
#  'Rosella Avenue': 1,
#  'Rosemont Avenue': 77,
#  'Ross Avenue': 1,
#  'Route 42': 1,
#  'Rutgers Court': 6,
#  'Saddlebrook Court': 16,
#  'Sadler Circle': 7,
#  'Saint Gregory Street': 1,
#  'Sandman Drive': 12,
#  'Scott Boulevard': 2,
#  'Scranton Court': 9,
#  'Seay Court': 8,
#  'Section Road': 1,
#  'Seminole Drive': 13,
#  'Service Road': 1,
#  'Shadowwood Court': 15,
#  'Shady Lane': 3,
#  'Shallow Creek Drive': 18,
#  'Shallowbrook Court': 22,
#  'Shaw Avenue': 2,
#  'Shenandoah Trace': 15,
#  'Sherilyn Lane': 1,
#  'Shingleoak Drive': 17,
#  'Shoemaker Drive': 30,
#  'Shoreline Way': 14,
#  'Silas Lane': 3,
#  'Silver Fox Court': 3,
#  'Sinclair Court': 9,
#  'Sioux Drive': 18,
#  'Slade Road ': 1,
#  'Sleepy Ridge Drive': 27,
#  'Snider Road': 1,
#  'Soaring Breezes': 1,
#  'Somerset Lane': 33,
#  'Sonata Drive': 10,
#  'Souffle Circle': 23,
#  'South Cooper Avenue': 2,
#  'South Fort Thomas Avenue': 3,
#  'South Fort Thomas Avnue': 1,
#  'South Front Street': 1,
#  'South Lebanon Road': 38,
#  'South Mason Montgomery Road': 1,
#  'South Miami Avenue': 6,
#  'South Pine Drive': 1,
#  'South State Line Road': 3,
#  'Southbend Court': 9,
#  'Spring Grove Avenue': 4,
#  'Spring Mill Way': 1,
#  'Springfield Pike': 1,
#  'Spruce Drive': 2,
#  'Spyglass Lane': 5,
#  'Stagge Road': 4,
#  'State Road': 1,
#  'State Route 276': 2,
#  'State Route 28': 11,
#  'State Route 42': 1,
#  'State Route 63': 2,
#  'Stevenson Lane': 1,
#  'Stillmeadow Drive': 1,
#  'Stockton Court': 24,
#  'Stockton Drive': 74,
#  'Stone Creek Boulevard': 2,
#  'Stone Point Court': 8,
#  'Stonebridge Drive': 23,
#  'Stonebridge Farm': 5,
#  'Stonebridge Way': 19,
#  'Stonelick Williams Corner Road': 1,
#  'Stonemark Lane': 19,
#  'Stonemasters Drive': 41,
#  'Stratford Avenue': 2,
#  'Stratford Court': 32,
#  'Streamside Drive': 30,
#  'Sugar Tree Drive': 2,
#  'Sugarwood Court': 5,
#  'Sunrise Drive': 80,
#  'Sycamore Avenue': 5,
#  'Sycamore Street': 7,
#  'Sylvian Drive': 3,
#  'Symbola Drive': 10,
#  'Symmes Creek Drive': 29,
#  'Symmes Hill Court': 6,
#  'Symmes Knoll Court': 14,
#  'Symmes Landing Drive': 21,
#  'Symmes Ridge Lane': 26,
#  'Symmes Trace Court': 12,
#  'Symmes Valley Drive': 31,
#  'Symmes View Court': 13,
#  'Taft Road Lane': 4,
#  'Tall Timber Drive': 11,
#  'Tanglewood Drive': 13,
#  'Thistlehill Drive': 29,
#  'Thomas Paxton Court': 8,
#  'Thorobred Road': 26,
#  'Tiger Trail': 1,
#  'Timber Cove': 2,
#  'Timbercreek Drive': 1,
#  'Timberridge Drive': 42,
#  'Tradition Trail': 22,
#  'Traditions Turn': 10,
#  'Trailridge Court': 50,
#  'Trailwoods Drive': 20,
#  'Tri County Parkway': 1,
#  'Trotters Way': 1,
#  'Turtle Creek Drive': 12,
#  'Tuscarora Drive': 54,
#  'Tylers Place Boulevard': 1,
#  'Tylersville Road': 1,
#  'U.S. Highway 42': 1,
#  'US 50': 3,
#  'US HWY  42 #A': 1,
#  'US-50': 3,
#  'Union Cemetery Road': 40,
#  'Unioncreek Lane': 4,
#  'University Drive': 1,
#  'Valley Forge Drive': 11,
#  'Valley View Lane': 4,
#  'Valley Woods Court': 8,
#  'Vanderbilt Drive': 24,
#  'Vera Lois Drive': 15,
#  'Victor Street': 2,
#  'Village Gate Lane': 18,
#  'Vine St': 1,
#  'Vine Street': 51,
#  'Voice of America Centre Drive': 1,
#  'Voice of America Drive': 1,
#  'W Clifton Ave': 1,
#  'W State Road': 1,
#  'Walnut Ridge Drive': 9,
#  'Walnut Street': 30,
#  'Wards Corner Road': 106,
#  'Warner': 1,
#  'Warsaw Avenue': 1,
#  'Washington Avenue': 2,
#  'Washington Street': 3,
#  'Waterford Place': 11,
#  'Waterfront Drive': 1,
#  'Waters Edge': 8,
#  'Waters Edge Court': 29,
#  'Wayne Madison Road': 1,
#  'Weatherstone Court': 28,
#  'Weeping Willow Court': 8,
#  'Wesley Drive': 14,
#  'West 12th Street': 3,
#  'West 14th Street': 1,
#  'West 3rd Street': 2,
#  'West 4th Street': 18,
#  'West 6th Street': 21,
#  'West 7th Street': 29,
#  'West 8th Street': 3,
#  'West 9th Street': 6,
#  'West Clifton Street': 1,
#  'West Court Street': 4,
#  'West Daniels Street': 1,
#  'West Eighth Street': 1,
#  'West Elder Street': 1,
#  'West Fourth Street': 1,
#  'West Galbraith Road ': 1,
#  'West Hanna Avenue': 24,
#  'West Kemper Road': 7,
#  'West Knollwood Circle': 7,
#  'West Loveland Avenue': 52,
#  'West Main Street': 43,
#  'West McMicken Avenue': 53,
#  'West McMillan Avenue': 1,
#  'West Pete Rose Way': 1,
#  'West River Center Boulevard': 1,
#  'West Sharon Road': 1,
#  'West United States Highway 22 and 3': 1,
#  'Westbourne Drive': 1,
#  'Wheaton Court': 5,
#  'Wheeler Street': 8,
#  'Whetsel Ave': 1,
#  'Whirlaway Terrace': 13,
#  'Whispering Springs Drive': 1,
#  'White Chapel Lane': 1,
#  'White Rose Court': 11,
#  'Wildwood Court': 7,
#  'Wilkins Boulevard': 4,
#  'William Howard Taft Road': 26,
#  'Willow Drive': 21,
#  'Willow Road': 6,
#  'Willowrun Lane': 15,
#  'Wilmar Avenue': 1,
#  'Wilmer Avenue': 1,
#  'Wilmington Drive': 26,
#  'Windfield Court': 18,
#  'Windfield Drive': 26,
#  'Winding Woods Drive': 14,
#  'Windrift Court': 7,
#  'Windy Hill Court': 13,
#  'Windy Hollow': 29,
#  'Winfield Avenue': 36,
#  'Wittenburg Drive': 23,
#  'Woodburn Avenue': 7,
#  'Woodcrest Drive': 51,
#  'Woodlake Court': 13,
#  'Woodridge Court': 7,
#  'Woods Trail Lane': 9,
#  'Woodsdale Road': 1,
#  'Woodside Place': 1,
#  'Woodsong Pass': 10,
#  'Woodvalley Court': 1,
#  'Woodwind Drive': 29,
#  'Wooster Pike': 3,
#  'Worldwide Boulevard': 5,
#  'firshade ter': 1,
#  'hamilton Avenue': 1,
#  'sandman Drive': 1,
#  'vine street': 1}

# %%
print "STATES:"
pprint.pprint(dict(states))
print "Postal Codes:"
pprint.pprint(dict(postcodes))
print "CITIES:"
pprint.pprint(dict(cities))
# Out:
# STATES:
# {'FL': 1,
#  'IN': 4,
#  'KY': 87,
#  'Kentucky': 1,
#  'OH': 6365,
#  'OH - Ohio': 1,
#  'OHIO': 1,
#  'Oh': 2,
#  'Ohio': 8,
#  'Ohop': 1,
#  'ky': 2,
#  'ohio': 1}
# Postal Codes:
# {'33321': 1,
#  '41005': 10,
#  '41011': 8,
#  '41014': 2,
#  '41015': 22,
#  '41017': 14,
#  '41018': 26,
#  '41042': 18,
#  '41051': 3,
#  '41071': 4,
#  '41073': 6,
#  '41075': 7,
#  '41076': 3,
#  '41080': 1,
#  '41091': 3,
#  '41094': 2,
#  '45001': 1,
#  '45002': 47,
#  '45011': 5,
#  '45014-4108': 3,
#  '45036': 3,
#  '45039': 6,
#  '45040': 15,
#  '45067': 3,
#  '45069': 8,
#  '45101': 1,
#  '45102': 1,
#  '45103': 8,
#  '45103-9707': 1,
#  '45140': 5773,
#  '4515': 1,
#  '45150': 48,
#  '45160': 9,
#  '45202': 377,
#  '45203': 4,
#  '45204': 3,
#  '45205': 3,
#  '45206': 11,
#  '45208': 58,
#  '45208-2017': 1,
#  '45208-2101': 2,
#  '45209': 12,
#  '45211': 90,
#  '45212': 1,
#  '45214': 1,
#  '45215': 8,
#  '45217': 1,
#  '45218': 1,
#  '45219': 58,
#  '45220': 17,
#  '45220-1405': 1,
#  '45223': 15,
#  '45223-1806': 1,
#  '45224': 2,
#  '45225': 3,
#  '45226': 2,
#  '45227': 4,
#  '45229': 1,
#  '45230': 1,
#  '45231': 1,
#  '45232': 1,
#  '45236': 7,
#  '45236-4202': 1,
#  '45238': 3,
#  '45239': 4,
#  '45240': 7,
#  '45241': 23,
#  '45242': 7,
#  '45243': 1,
#  '45244': 1,
#  '45245': 5,
#  '45246': 6,
#  '45247': 11,
#  '45248': 1,
#  '45249': 31,
#  '45251': 4,
#  '45255': 4,
#  '47025': 1}
# CITIES:
# {'Addyston': 1,
#  'Amberley Village': 1,
#  'Amelia': 1,
#  'Batavia': 7,
#  'Bellevue': 5,
#  'Blue Ash': 3,
#  'Burlington': 11,
#  'CIncinnati': 1,
#  'Cheviot': 1,
#  'Cincinnati': 842,
#  'Cincinnati, OH': 6,
#  'Cincinnati, Ohio': 1,
#  'Cincinnati, oh': 1,
#  'Cincinnati; Symmes': 11,
#  'Cincinnati;Blue Ash': 1,
#  'Cincinnati;Symmes': 16,
#  'Cleves': 48,
#  'Cold Spring': 3,
#  'Covington': 138,
#  'Crescent Springs': 10,
#  'Deer Park': 2,
#  'Deerfield Township': 5,
#  'Edgewood': 1,
#  'Elsmere': 2,
#  'Erlanger': 24,
#  'Florence': 16,
#  'Forest Park': 2,
#  'Fort Mitchell': 1,
#  'Fort Thomas': 1,
#  'Fort Wright': 2,
#  'Greenhills': 1,
#  'Hamilton': 5,
#  'Hartwell': 1,
#  'Hebron': 5,
#  'Highland Heights': 2,
#  'Independence': 3,
#  'Latonia': 1,
#  'Lebanon': 3,
#  'Liberty Township': 1,
#  'Lockland': 3,
#  'Loveland': 5808,
#  'Maineville': 6,
#  'Mariemont': 3,
#  'Mason': 17,
#  'Milford': 49,
#  'Montgomery': 66,
#  'Newport': 2,
#  'Newport, Kentucky': 5,
#  'Newtown': 1,
#  'North Bend': 2,
#  'Owensville': 9,
#  'Petersburg': 1,
#  'Reading': 4,
#  'Sharonville': 12,
#  'Tamarac': 1,
#  'Taylor Mill': 21,
#  'Trenton': 3,
#  'Union': 36,
#  'Villa Hills': 2,
#  'Walton': 2,
#  'West Chester': 12,
#  'West Harrison': 1,
#  'cincinnati': 1,
#  'forest Park': 1,
#  'fort thomas': 1}

# %%
street_mapping = {"Ave": "Avenue",
           "Avene": "Avenue",
           "Avnue": "Avenue",
           "avenue": "Avenue",
           "State" : "Avenue",
           "Dr" : "Drive",
           "dr." : "Drive",
           "meadow" : "Meadow Drive",
           "Rd.": "Road",
           "Rd": "Road",
           "St": "Street",
           "street" : "Street",
           "ter" : "Terrace"}

def update_name(name, mapping):
    for key in mapping:
        if name.endswith(key):
            type_start = name.find(key)
            name = name[:type_start] + mapping[key]
    return name

# %%
def test():
    #st_types, st_names, states, postcodes, cities = audit(OSMFILE)
    #pprint.pprint(dict(st_types))
    print "UPDATED NAMES:"

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, street_mapping)
            if better_name != name:
                print name, "=>", better_name
            
test()
# Out:
# UPDATED NAMES:
# Kemper meadow => Kemper Meadow Drive
# Princeton Rd => Princeton Road
# Bridgetown Rd => Bridgetown Road
# Ritchie State => Ritchie Avenue
# firshade ter => firshade Terrace
# Montgomery Rd. => Montgomery Road
# Hamilton avenue => Hamilton Avenue
# Beckett Center Dr => Beckett Center Drive
# Clough Woods Dr => Clough Woods Drive
# Cincinnati Mills Dr => Cincinnati Mills Drive
# Genntown Dr => Genntown Drive
# 215 Calhoun St => 215 Calhoun Street
# Vine St => Vine Street
# Clark St => Clark Street
# Greenup St => Greenup Street
# Chickasaw St => Chickasaw Street
# South Fort Thomas Avnue => South Fort Thomas Avenue
# Ludlow Avene => Ludlow Avenue
# vine street => vine Street
# Whetsel Ave => Whetsel Avenue
# W Clifton Ave => W Clifton Avenue
# Kenard Ave => Kenard Avenue
# Kemper Meadow dr. => Kemper Meadow Drive

# %%
state_mapping = {'Oh': "OH", 
                 'oh': "OH", 
                 'OHIO': "OH", 
                 'Ohop': "OH", 
                 'ohio': "OH", 
                 'Ohio': "OH", 
                 'OH - Ohio': "OH", 
                 'Kentucky': "KY", 
                 'ky': "KY"}

def update_state(name, mapping):
    # change state name to 2-letter code
    for key in mapping:
        if name == key:
            name = mapping[key]
    return name

city_mapping = { 'CIncinnati': "Cincinnati", 
                 'cincinnati': "Cincinnati", 
                 'Cincinnati, OH': "Cincinnati", 
                 'Cincinnati, Ohio': "Cincinnati", 
                 'Cincinnati, Oh': "Cincinnati", 
                 'Cincinnati, oh': "Cincinnati", 
                 'Cincinnati; Symmes': "Symmes Township",
                 'Cincinnati;Blue Ash': "Blue Ash", 
                 'Cincinnati;Symmes': "Montgomery",
                 'Newport, Kentucky': "Newport",
                 'forest Park': "Forest Park",
                 'fort thomas': "Fort Thomas" }


def update_city(name, mapping):
    # fix inconsistent or incorrect city identifiers
    for key in mapping:
        if name == key:
            name = mapping[key]
    return name

def update_postcode(code):
    # strip suffix of postal code if present
    if len(code) > 5:
        return code[:5]
    else:
        return code

# %% [markdown]
# ## clean_cinci.py

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

    
def has_addr(element):
    for child in element:
        if child.tag == "tag":
            k = child.attrib["k"]
            if k.find("addr") != -1:
                return True
    return False


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        attributes = element.attrib
        node["type"] = element.tag
        node["created"] = {}
        
        if "lat" in attributes and "lon" in attributes:
            node["pos"] = [ float(attributes["lat"]), float(attributes["lon"]) ]
        if has_addr(element):
            node["address"] = {}
        
        for key in attributes:
            if key in CREATED:
                node["created"][key] = attributes[key]
            elif key != "lat" and key != "lon":
                node[key] = attributes[key]
        
        if element.findall("tag"):
            for child in element.iter("tag"):
                k = child.attrib["k"]
                v = child.attrib["v"]
                
                if k.find("addr") != -1:
                    new_key = k[5:]
                    if new_key.find(":") != -1:
                        pass
                    elif new_key == "street":
                        v = update_name(v, street_mapping)
                    elif new_key == "state":
                        v = update_state(v, state_mapping) 
                    elif new_key == "postcode":
                        v = update_postcode(v)
                    elif new_key == "city":
                        comma = v.find(",")
                        if comma != -1:
                            state = v[comma + 2:]
                            state = update_state(state, state_mapping)
                            node["address"]["state"] = state
                        v = update_city(v, city_mapping)
                    node["address"][new_key] = v
                elif problemchars.search(k):
                    pass
                else:
                    node[k] = v
        
        if element.tag == "way":
            node["node_refs"] = []
            if element.findall("nd"):
                for child in element.iter("nd"):
                    value = child.attrib["ref"]
                    node["node_refs"].append(value)
                    
        return node
    else:
        return None



def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        # get an iterable & turn it into an iterator
        context = ET.iterparse(file_in, events=("start", "end"))
        context = iter(context)
        # get the root element
        event, root = context.next()

        for event, element in context:
            el = shape_element(element)
            if event == "end" and el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
                root.clear()
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map('sample.osm', pretty=False)
    pprint.pprint(data)

if __name__ == "__main__":
    test()
# Out:
# [{'created': {'changeset': '12642091',
#               'timestamp': '2012-08-07T08:15:12Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '17'},
#   'id': '60513020',
#   'pos': [39.4307416, -84.341689],
#   'type': 'node'},
#  {'created': {'changeset': '757389',
#               'timestamp': '2009-03-08T10:26:19Z',
#               'uid': '47647',
#               'user': 'drewp',
#               'version': '18'},
#   'id': '60532208',
#   'pos': [39.3083765, -84.436355],
#   'type': 'node'},
#  {'created': {'changeset': '961717',
#               'timestamp': '2009-04-25T23:27:07Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '28'},
#   'id': '60532283',
#   'pos': [39.1563554, -84.5367628],
#   'type': 'node'},
#  {'created': {'changeset': '27784422',
#               'timestamp': '2014-12-29T19:08:09Z',
#               'uid': '1108251',
#               'user': 'Nate_Wessel',
#               'version': '4'},
#   'id': '75422682',
#   'pos': [38.9892297, -84.2994103],
#   'source': 'tiger:boundaries',
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#               'timestamp': '2008-12-06T16:59:46Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '238',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1064925',
#   'id': '153871915',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Kennedy Heights',
#   'place': 'hamlet',
#   'pos': [39.1856147, -84.408274],
#   'type': 'node'},
#  {'census:population': '2534;2006',
#   'created': {'changeset': '21914989',
#               'timestamp': '2014-04-24T18:57:25Z',
#               'uid': '2015820',
#               'user': 'Cobra50',
#               'version': '3'},
#   'ele': '151',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1056814',
#   'highway': 'traffic_signals',
#   'id': '153913543',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Cleves',
#   'place': 'village',
#   'population': '2534',
#   'pos': [39.162278, -84.7492122],
#   'type': 'node'},
#  {'created': {'changeset': '177010',
#               'timestamp': '2008-12-06T17:02:21Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '204',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1048730',
#   'id': '153965079',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Faxon Hills',
#   'place': 'hamlet',
#   'pos': [39.1325598, -84.437719],
#   'type': 'node'},
#  {'created': {'changeset': '29341687',
#               'timestamp': '2015-03-09T00:12:51Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '5'},
#   'ele': '255',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Clermont',
#   'gnis:County_num': '025',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1048797',
#   'id': '153998719',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Clermont,Ohio,Ohio,OH,USA',
#   'name': 'Goshen',
#   'place': 'village',
#   'pos': [39.2333935, -84.1613239],
#   'type': 'node',
#   'wikipedia': 'en:Goshen, Ohio'},
#  {'created': {'changeset': '177010',
#               'timestamp': '2008-12-06T17:04:12Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '150',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1066708',
#   'id': '154034194',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Finney',
#   'place': 'hamlet',
#   'pos': [39.1189467, -84.7885602],
#   'type': 'node'},
#  {'census:population': '3479;2006',
#   'created': {'changeset': '145015',
#               'timestamp': '2008-12-06T14:52:04Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '255',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Boone',
#   'gnis:County_num': '015',
#   'gnis:ST_alpha': 'KY',
#   'gnis:ST_num': '21',
#   'gnis:id': '505762',
#   'id': '154075381',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Boone,Kentucky,Ky.,KY,USA',
#   'name': 'Union',
#   'place': 'village',
#   'population': '3479',
#   'pos': [38.9458951, -84.680501],
#   'type': 'node'},
#  {'created': {'changeset': '145015',
#               'timestamp': '2008-12-06T14:52:31Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '275',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Boone',
#   'gnis:County_num': '015',
#   'gnis:ST_alpha': 'KY',
#   'gnis:ST_num': '21',
#   'gnis:id': '494517',
#   'id': '154114784',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Boone,Kentucky,Ky.,KY,USA',
#   'name': 'Hopeful Heights',
#   'place': 'hamlet',
#   'pos': [39.0011719, -84.6577228],
#   'type': 'node'},
#  {'created': {'changeset': '177010',
#               'timestamp': '2008-12-06T17:07:08Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '149',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1059739',
#   'id': '154160714',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Eightmile',
#   'place': 'hamlet',
#   'pos': [39.0345066, -84.332716],
#   'type': 'node'},
#  {'created': {'changeset': '145015',
#               'timestamp': '2008-12-06T14:33:56Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '150',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Dearborn',
#   'gnis:County_num': '029',
#   'gnis:ST_alpha': 'IN',
#   'gnis:ST_num': '18',
#   'gnis:id': '437675',
#   'id': '154191992',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Dearborn,Indiana,Ind.,IN,USA',
#   'name': 'Lawrenceburg Junction',
#   'place': 'hamlet',
#   'pos': [39.1306126, -84.8424507],
#   'type': 'node'},
#  {'created': {'changeset': '145015',
#               'timestamp': '2008-12-06T14:53:50Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '255',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Kenton',
#   'gnis:County_num': '117',
#   'gnis:ST_alpha': 'KY',
#   'gnis:ST_num': '21',
#   'gnis:id': '504787',
#   'id': '154303562',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Kenton,Kentucky,Ky.,KY,USA',
#   'name': 'Summit Hills Heights',
#   'place': 'hamlet',
#   'pos': [39.0061722, -84.5529985],
#   'type': 'node'},
#  {'created': {'changeset': '177010',
#               'timestamp': '2008-12-06T17:10:53Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '243',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Hamilton',
#   'gnis:County_num': '061',
#   'gnis:ST_alpha': 'OH',
#   'gnis:ST_num': '39',
#   'gnis:id': '1048545',
#   'id': '154339402',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Hamilton,Ohio,Ohio,OH,USA',
#   'name': 'Brentwood',
#   'place': 'hamlet',
#   'pos': [39.2283911, -84.5296663],
#   'type': 'node'},
#  {'created': {'changeset': '145015',
#               'timestamp': '2008-12-06T14:54:51Z',
#               'uid': '3582',
#               'user': 'davidearl',
#               'version': '2'},
#   'ele': '159',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Kenton',
#   'gnis:County_num': '117',
#   'gnis:ST_alpha': 'KY',
#   'gnis:ST_num': '21',
#   'gnis:id': '506650',
#   'id': '154382508',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Kenton,Kentucky,Ky.,KY,USA',
#   'name': 'White Villa',
#   'place': 'hamlet',
#   'pos': [38.8792317, -84.4504952],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:17Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161940132',
#   'pos': [38.954368, -84.821275],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:18Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161940235',
#   'pos': [38.975782, -84.823192],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:20Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161940432',
#   'pos': [38.947062, -84.613528],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:21Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161940595',
#   'pos': [39.033019, -84.841855],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:24Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161940827',
#   'pos': [39.105144, -84.741097],
#   'type': 'node'},
#  {'created': {'changeset': '20361684',
#               'timestamp': '2014-02-03T21:40:18Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '3'},
#   'id': '161940929',
#   'pos': [39.0996867, -84.7435942],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:30Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161941224',
#   'pos': [38.935442, -84.794673],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:35Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161941648',
#   'pos': [38.963633, -84.764614],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:04Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161942070',
#   'pos': [38.998391, -84.646797],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:45Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161942500',
#   'pos': [38.881351, -84.62258],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:51Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161943052',
#   'pos': [38.970431, -84.678399],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:38:55Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161943288',
#   'pos': [39.071508, -84.653849],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:39:03Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161943942',
#   'pos': [39.07172, -84.748944],
#   'type': 'node'},
#  {'created': {'changeset': '14800222',
#               'timestamp': '2013-01-26T22:59:48Z',
#               'uid': '1108251',
#               'user': 'Nate_Wessel',
#               'version': '3'},
#   'id': '161944220',
#   'pos': [38.9630071, -84.7046871],
#   'type': 'node'},
#  {'created': {'changeset': '3625507',
#               'timestamp': '2010-01-15T16:40:52Z',
#               'uid': '24807',
#               'user': 'mikecanann',
#               'version': '3'},
#   'id': '161944859',
#   'pos': [39.088927, -84.668737],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:39:17Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161945275',
#   'pos': [38.985293, -84.639739],
#   'type': 'node'},
#  {'created': {'changeset': '5244726',
#               'timestamp': '2010-07-17T18:44:41Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161945665',
#   'pos': [38.9966651, -84.7138801],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:19Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161946249',
#   'pos': [39.015996, -84.732391],
#   'type': 'node'},
#  {'created': {'changeset': '19434322',
#               'timestamp': '2013-12-13T15:07:04Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '3'},
#   'id': '161947520',
#   'pos': [39.0116905, -84.7107876],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:39:43Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161948010',
#   'pos': [38.987761, -84.642426],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:39:48Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161948427',
#   'pos': [38.997084, -84.708324],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:28Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161949209',
#   'pos': [39.01264, -84.632188],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:39:58Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161949577',
#   'pos': [39.081381, -84.711224],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:29Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161949855',
#   'pos': [38.940291, -84.632148],
#   'type': 'node'},
#  {'created': {'changeset': '19053711',
#               'timestamp': '2013-11-22T13:25:53Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161950463',
#   'pos': [39.010839, -84.7447216],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:40:25Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161950864',
#   'pos': [38.941161, -84.634044],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:40:28Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161951314',
#   'pos': [39.070862, -84.657843],
#   'type': 'node'},
#  {'created': {'changeset': '13015560',
#               'timestamp': '2012-09-06T20:45:17Z',
#               'uid': '121241',
#               'user': 'zephyr',
#               'version': '5'},
#   'id': '161951634',
#   'pos': [39.022075, -84.7667518],
#   'power': 'tower',
#   'type': 'node'},
#  {'created': {'changeset': '14718549',
#               'timestamp': '2013-01-20T11:18:10Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161952092',
#   'pos': [38.943472, -84.7511033],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:39Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161952584',
#   'pos': [38.946036, -84.710622],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:41Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161952994',
#   'pos': [38.917526, -84.630641],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:40:50Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161953145',
#   'pos': [39.053467, -84.625799],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:42Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161953531',
#   'pos': [38.910149, -84.660742],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:01Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161954032',
#   'pos': [39.061903, -84.784059],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:07Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161954594',
#   'pos': [38.984054, -84.642522],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161955046',
#   'pos': [38.916346, -84.678443],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:15Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161955291',
#   'pos': [39.106504, -84.752601],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:22Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161955929',
#   'pos': [39.072724, -84.654832],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:48Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161956065',
#   'pos': [38.920484, -84.778123],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:27Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161956275',
#   'pos': [39.002687, -84.648518],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:30Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161956579',
#   'pos': [38.985824, -84.639124],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:36Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161957077',
#   'pos': [38.903787, -84.807999],
#   'type': 'node'},
#  {'created': {'changeset': '8602849',
#               'timestamp': '2011-07-01T20:33:51Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161957666',
#   'pos': [39.0787503, -84.7741854],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:20:56Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161957827',
#   'pos': [38.972732, -84.78398],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:47Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161958078',
#   'pos': [39.088771, -84.792988],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:41:51Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161958511',
#   'pos': [39.013344, -84.712925],
#   'type': 'node'},
#  {'created': {'changeset': '14715908',
#               'timestamp': '2013-01-20T04:58:35Z',
#               'uid': '1108251',
#               'user': 'Nate_Wessel',
#               'version': '3'},
#   'id': '161959304',
#   'pos': [38.9209138, -84.7350772],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:01Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161959604',
#   'pos': [38.982523, -84.613693],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:20Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161959777',
#   'pos': [38.98184, -84.614635],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:22Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '161959913',
#   'pos': [39.071136, -84.655733],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:04Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161960619',
#   'pos': [38.975947, -84.612501],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:04Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161960788',
#   'pos': [38.970465, -84.612248],
#   'type': 'node'},
#  {'created': {'changeset': '9951982',
#               'timestamp': '2011-11-26T08:12:41Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161961210',
#   'pos': [39.0274234, -84.7582662],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:08Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161961930',
#   'pos': [38.973726, -84.628647],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:48Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161962156',
#   'pos': [39.08442, -84.738089],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:50Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161962267',
#   'pos': [39.098544, -84.749122],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:52Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161962370',
#   'pos': [39.103256, -84.758383],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:42:55Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161962678',
#   'pos': [39.007825, -84.689023],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:11Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161962808',
#   'pos': [38.944743, -84.765154],
#   'type': 'node'},
#  {'created': {'changeset': '20334984',
#               'timestamp': '2014-02-02T14:27:29Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '3'},
#   'id': '161962983',
#   'pos': [38.8834022, -84.645417],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:00Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963127',
#   'pos': [39.095771, -84.724237],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:02Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963251',
#   'pos': [39.081746, -84.735575],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:05Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963421',
#   'pos': [39.070115, -84.702141],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:08Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963545',
#   'pos': [39.03805, -84.695025],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:12Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963646',
#   'pos': [39.018187, -84.687472],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:11Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963745',
#   'pos': [38.942619, -84.64857],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:12Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161963865',
#   'pos': [39.029005, -84.729976],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:14Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161964018',
#   'pos': [39.088279, -84.708308],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:16Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161964160',
#   'pos': [38.971347, -84.647222],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:18Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161964335',
#   'pos': [39.006929, -84.686857],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:20Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161964492',
#   'pos': [39.000565, -84.63308],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:25Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161964943',
#   'pos': [38.90161, -84.64319],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:26Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161965150',
#   'pos': [39.018699, -84.634471],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:28Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161965292',
#   'pos': [39.115277, -84.737198],
#   'type': 'node'},
#  {'created': {'changeset': '20247210',
#               'timestamp': '2014-01-28T13:46:21Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '4'},
#   'id': '161965409',
#   'pos': [38.9436829, -84.6401137],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:19Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161965534',
#   'pos': [38.961162, -84.69293],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:20Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161965683',
#   'pos': [39.033657, -84.731096],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:35Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161965843',
#   'pos': [38.942143, -84.630963],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:21Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966019',
#   'pos': [38.953215, -84.630222],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:22Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966128',
#   'pos': [38.98722, -84.690467],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:40Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966249',
#   'pos': [39.000436, -84.680359],
#   'type': 'node'},
#  {'created': {'changeset': '19053711',
#               'timestamp': '2013-11-22T13:25:53Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'id': '161966434',
#   'pos': [39.0143124, -84.7273841],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:44Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966549',
#   'pos': [38.985424, -84.825544],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:46Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966694',
#   'pos': [38.993165, -84.667],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:47Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966840',
#   'pos': [38.955425, -84.647743],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:25Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161966991',
#   'pos': [38.996737, -84.659964],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:43:52Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161967197',
#   'pos': [38.966929, -84.630319],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:26Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161967306',
#   'pos': [39.022249, -84.637632],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:10Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161967427',
#   'pos': [39.104473, -84.71978],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161967551',
#   'pos': [38.931054, -84.653193],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:14Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161967745',
#   'pos': [39.089013, -84.714952],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:18Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968023',
#   'pos': [38.875174, -84.652443],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:19Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968138',
#   'pos': [38.878619, -84.669551],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:21Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968256',
#   'pos': [38.879954, -84.688862],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:22Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968366',
#   'pos': [38.885702, -84.723619],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:31Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968481',
#   'pos': [38.889109, -84.745151],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:25Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968578',
#   'pos': [38.889615, -84.760722],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:26Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968646',
#   'pos': [38.893273, -84.774822],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:28Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968741',
#   'pos': [38.89483, -84.788483],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:29Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968832',
#   'pos': [38.90799, -84.818122],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:34Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161968943',
#   'pos': [38.910764, -84.833219],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:35Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161969196',
#   'pos': [39.016095, -84.688637],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:36Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161969352',
#   'pos': [39.007651, -84.699825],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:36Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161969514',
#   'pos': [38.989019, -84.68847],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:38Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161969689',
#   'pos': [39.04293, -84.69993],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:38Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161969840',
#   'pos': [39.009646, -84.719425],
#   'type': 'node'},
#  {'created': {'changeset': '5958752',
#               'timestamp': '2010-10-05T06:10:55Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '3'},
#   'highway': 'turning_circle',
#   'id': '161970042',
#   'pos': [38.971987, -84.641941],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:44Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970191',
#   'pos': [38.915263, -84.680024],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:40Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970326',
#   'pos': [38.955967, -84.630363],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:47Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970457',
#   'pos': [38.937043, -84.637064],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:49Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970607',
#   'pos': [38.955791, -84.660175],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:42Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970734',
#   'pos': [39.00924, -84.643278],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:52Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161970890',
#   'pos': [39.043664, -84.729341],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:53Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971017',
#   'pos': [39.062525, -84.62759],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:56Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971264',
#   'pos': [39.051961, -84.626969],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:44:57Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971373',
#   'pos': [38.924987, -84.685218],
#   'type': 'node'},
#  {'created': {'changeset': '19976696',
#               'timestamp': '2014-01-13T18:25:18Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '3'},
#   'id': '161971495',
#   'pos': [38.9984785, -84.6773985],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:21:44Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971744',
#   'pos': [38.930507, -84.655545],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:02Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971877',
#   'pos': [39.01964, -84.719898],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:04Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161971996',
#   'pos': [38.995844, -84.66192],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:05Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161972118',
#   'pos': [38.981834, -84.661157],
#   'type': 'node'},
#  {'created': {'changeset': '19347141',
#               'timestamp': '2013-12-08T19:53:22Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '3'},
#   'id': '161972278',
#   'pos': [38.9487683, -84.6563736],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:10Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161972566',
#   'pos': [38.993112, -84.624505],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:12Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161972691',
#   'pos': [38.966188, -84.616518],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161972806',
#   'pos': [38.933327, -84.626413],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:15Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161972913',
#   'pos': [38.896579, -84.61055],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:17Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973025',
#   'pos': [38.876439, -84.611155],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:06Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973186',
#   'pos': [39.0245, -84.722593],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:06Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973296',
#   'pos': [39.011631, -84.708589],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:22Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973429',
#   'pos': [38.928495, -84.671756],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:23Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973542',
#   'pos': [38.906106, -84.633183],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:25Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973674',
#   'pos': [38.986249, -84.697989],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:27Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973871',
#   'pos': [38.99951, -84.760866],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:28Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161973986',
#   'pos': [39.004228, -84.670392],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:30Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974110',
#   'pos': [38.972133, -84.745112],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:31Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974230',
#   'pos': [39.00189, -84.685612],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:34Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974413',
#   'pos': [39.069181, -84.692649],
#   'type': 'node'},
#  {'created': {'changeset': '19377965',
#               'timestamp': '2013-12-10T14:13:33Z',
#               'uid': '1813535',
#               'user': 'lrhill',
#               'version': '4'},
#   'id': '161974531',
#   'pos': [38.9867631, -84.7116788],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:38Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974690',
#   'pos': [39.021479, -84.712591],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:12Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974861',
#   'pos': [38.972803, -84.648348],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161974979',
#   'pos': [39.021252, -84.757108],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975107',
#   'pos': [38.961998, -84.654503],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:45Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975223',
#   'pos': [38.963304, -84.643213],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:46Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975381',
#   'pos': [38.987765, -84.618304],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:48Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975527',
#   'pos': [38.999466, -84.621888],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:45:50Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975660',
#   'pos': [38.994583, -84.636932],
#   'type': 'node'},
#  {'created': {'changeset': '2323463',
#               'timestamp': '2009-08-31T09:22:15Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975807',
#   'pos': [39.029354, -84.7473],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:46:09Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161975986',
#   'pos': [38.990613, -84.621495],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:46:11Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '161976142',
#   'pos': [38.941774, -84.761438],
#   'type': 'node'},
#  {'created': {'changeset': '2900979',
#               'timestamp': '2009-10-20T09:46:13Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
# ...
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '42'},
#   'id': '301944096',
#   'pos': [39.3359759, -84.2542349],
#   'type': 'node'},
#  {'created': {'changeset': '612669',
#               'timestamp': '2009-02-22T08:25:07Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '42'},
#   'id': '301944140',
#   'pos': [39.325234, -84.2520806],
#   'type': 'node'},
#  {'created': {'changeset': '612669',
#               'timestamp': '2009-02-22T08:25:06Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '42'},
#   'id': '302108857',
#   'pos': [39.3363842, -84.2546631],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:29:22Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302118121',
#   'pos': [39.26434, -84.3199172],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:31:12Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302118630',
#   'pos': [39.2653568, -84.3203206],
#   'type': 'node'},
#  {'created': {'changeset': '850294',
#               'timestamp': '2009-01-29T05:31:12Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '2'},
#   'id': '302123169',
#   'pos': [39.2660346, -84.319222],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:54:36Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302123632',
#   'pos': [39.2692242, -84.3250928],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:54:40Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302123711',
#   'pos': [39.2690381, -84.3249383],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:55:17Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302123865',
#   'pos': [39.269264, -84.325007],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:56:29Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302124148',
#   'pos': [39.2678221, -84.3243804],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:58:20Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302124531',
#   'pos': [39.2694235, -84.3259683],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T22:59:38Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302124834',
#   'pos': [39.268367, -84.3279939],
#   'type': 'node'},
#  {'created': {'changeset': '71062',
#               'timestamp': '2008-10-04T23:03:29Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302125849',
#   'pos': [39.2738156, -84.3280454],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:06:54Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302197183',
#   'pos': [39.3747629, -84.2342863],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:08:22Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302197527',
#   'pos': [39.3750283, -84.2275829],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:08:24Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302197567',
#   'pos': [39.3774234, -84.2286901],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:09:18Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302197786',
#   'pos': [39.3639008, -84.2301836],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:10:04Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302197951',
#   'pos': [39.3626467, -84.2240381],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:31:23Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302203159',
#   'pos': [39.3491942, -84.2222528],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:34:50Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302203820',
#   'pos': [39.3402798, -84.2410326],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:36:30Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302204486',
#   'pos': [39.3340663, -84.2378053],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:38:54Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302205230',
#   'pos': [39.3336613, -84.2359943],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:38:56Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302205277',
#   'pos': [39.3351218, -84.2339172],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:38:57Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302205321',
#   'pos': [39.3324597, -84.2382688],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:39:49Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302205564',
#   'pos': [39.3376976, -84.2299432],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:41:14Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302205918',
#   'pos': [39.3453379, -84.227643],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:41:51Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206053',
#   'pos': [39.3437183, -84.2329044],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:43:09Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206307',
#   'pos': [39.3305477, -84.2290077],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:44:38Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206588',
#   'pos': [39.3284697, -84.2672367],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:45:32Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206736',
#   'pos': [39.3312315, -84.267065],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:46:36Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206875',
#   'pos': [39.3290406, -84.2708931],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:47:40Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302206995',
#   'pos': [39.3274207, -84.2726955],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:48:15Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207093',
#   'pos': [39.329346, -84.2779741],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:49:17Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207209',
#   'pos': [39.330946, -84.2766952],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:50:49Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207477',
#   'pos': [39.3272679, -84.2924108],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:51:29Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207599',
#   'pos': [39.3229323, -84.2909002],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:52:19Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207722',
#   'pos': [39.3208474, -84.2925653],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:53:16Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302207890',
#   'pos': [39.3203627, -84.2987537],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:54:09Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302208067',
#   'pos': [39.3217704, -84.3050365],
#   'type': 'node'},
#  {'created': {'changeset': '444698',
#               'timestamp': '2009-04-12T10:45:45Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '2'},
#   'id': '302208264',
#   'pos': [39.3277991, -84.2979383],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:55:47Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302208442',
#   'pos': [39.3274339, -84.2999811],
#   'type': 'node'},
#  {'created': {'changeset': '14080757',
#               'timestamp': '2012-11-28T23:53:42Z',
#               'uid': '5453',
#               'user': 'wasat',
#               'version': '2'},
#   'id': '302208883',
#   'pos': [39.321078, -84.3211903],
#   'type': 'node'},
#  {'created': {'changeset': '14080757',
#               'timestamp': '2012-11-28T23:53:43Z',
#               'uid': '5453',
#               'user': 'wasat',
#               'version': '2'},
#   'id': '302208982',
#   'pos': [39.3212471, -84.3247064],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T07:58:53Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302209166',
#   'pos': [39.3249441, -84.3315754],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T08:03:16Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302209765',
#   'pos': [39.3186761, -84.3807134],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T08:08:57Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302210419',
#   'pos': [39.3234901, -84.4003086],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T08:13:29Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302210926',
#   'pos': [39.3252828, -84.4026861],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T08:20:19Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302211779',
#   'pos': [39.3274605, -84.3877859],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T08:28:01Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302212891',
#   'pos': [39.3061849, -84.4025058],
#   'type': 'node'},
#  {'created': {'changeset': '5256442',
#               'timestamp': '2010-07-18T23:54:04Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '2'},
#   'id': '302215039',
#   'pos': [39.3197284, -84.3858355],
#   'type': 'node'},
#  {'created': {'changeset': '4067547',
#               'timestamp': '2010-03-07T22:59:48Z',
#               'uid': '223675',
#               'user': 'moojieturtle',
#               'version': '2'},
#   'id': '302217026',
#   'pos': [39.3442949, -84.3749497],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:20:01Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302221125',
#   'pos': [39.3256944, -84.3719158],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:28:21Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302223037',
#   'pos': [39.3143997, -84.2781114],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:29:14Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302223256',
#   'pos': [39.3151036, -84.2714939],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:30:13Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302223462',
#   'pos': [39.3131712, -84.2731332],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:32:35Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302223978',
#   'pos': [39.3250305, -84.2683439],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:34:17Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302224600',
#   'pos': [39.3116438, -84.2446031],
#   'type': 'node'},
#  {'created': {'changeset': '3253296',
#               'timestamp': '2009-11-30T07:14:26Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '2'},
#   'id': '302224713',
#   'pos': [39.3124474, -84.2426634],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:37:19Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302224989',
#   'pos': [39.3227663, -84.2315054],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:38:10Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302225214',
#   'pos': [39.31938, -84.2355652],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:41:17Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '1'},
#   'id': '302226021',
#   'pos': [39.2987063, -84.2301922],
#   'type': 'node'},
#  {'created': {'changeset': '84575',
#               'timestamp': '2008-10-05T09:41:32Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen'

# %%
from pymongo import MongoClient
client = MongoClient('localhost:27017')
db = client.course

docs = db.cinci.find().count()
nodes = db.cinci.find({ "type" : "node" }).count()
ways = db.cinci.find({ "type" : "way" }).count()

print "Number of documents: ", docs
print "Number of nodes: ", nodes
print "Number of  ways: ", ways
# Out:
# Number of documents:  2255747
# Number of nodes:  1985219
# Number of  ways:  270488

# %%
user_list = db.cinci.distinct("created.user")
print "Number of distinct users:", len(user_list)
# Out:
# Number of distinct users: 565

# %% [markdown]
# ###Exploration of tags

# %%
pipeline = [
    { "$match" : { "highway" : { "$exists" : 1 } } },
    { "$group" : { "_id" : "$highway",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } },
    { "$limit" : 15 }
]
highway= db.cinci.aggregate(pipeline)

for item in highway:
    pprint.pprint(item)
# Out:
# {u'_id': u'residential', u'count': 29517}
# {u'_id': u'service', u'count': 25200}
# {u'_id': u'turning_circle', u'count': 11144}
# {u'_id': u'crossing', u'count': 9872}
# {u'_id': u'footway', u'count': 5854}
# {u'_id': u'bus_stop', u'count': 3158}
# {u'_id': u'tertiary', u'count': 2311}
# {u'_id': u'traffic_signals', u'count': 2104}
# {u'_id': u'track', u'count': 1124}
# {u'_id': u'motorway_link', u'count': 1026}
# {u'_id': u'secondary', u'count': 1015}
# {u'_id': u'path', u'count': 989}
# {u'_id': u'motorway', u'count': 898}
# {u'_id': u'primary', u'count': 622}
# {u'_id': u'unclassified', u'count': 593}

# %%
pipeline = [
    { "$match" : { "service" : { "$exists" : 1 } } },
    { "$group" : { "_id" : "$service",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } }
]
services = db.cinci.aggregate(pipeline)

for item in services:
    pprint.pprint(item)
# Out:
# {u'_id': u'driveway', u'count': 5249}
# {u'_id': u'parking_aisle', u'count': 3313}
# {u'_id': u'alley', u'count': 1399}
# {u'_id': u'spur', u'count': 365}
# {u'_id': u'yard', u'count': 352}
# {u'_id': u'drive-through', u'count': 91}
# {u'_id': u'siding', u'count': 58}
# {u'_id': u'parking', u'count': 7}
# {u'_id': u'emergency_access', u'count': 5}
# {u'_id': u'ramp', u'count': 1}
# {u'_id': u'loading', u'count': 1}
# {u'_id': u'drive_thru', u'count': 1}
# {u'_id': u'2', u'count': 1}
# {u'_id': u'drive_through', u'count': 1}
# {u'_id': u'weigh_station', u'count': 1}

# %%
pipeline = [
    { "$match" : { "amenity" : { "$exists" : 1 } } },
    { "$group" : { "_id" : "$amenity",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } },
    { "$limit" : 20 }
]
amenities = db.cinci.aggregate(pipeline)

for item in amenities:
    pprint.pprint(item)
# Out:
# {u'_id': u'parking', u'count': 2346}
# {u'_id': u'place_of_worship', u'count': 1296}
# {u'_id': u'school', u'count': 721}
# {u'_id': u'fuel', u'count': 613}
# {u'_id': u'restaurant', u'count': 504}
# {u'_id': u'fast_food', u'count': 406}
# {u'_id': u'bench', u'count': 341}
# {u'_id': u'bank', u'count': 245}
# {u'_id': u'grave_yard', u'count': 146}
# {u'_id': u'drinking_water', u'count': 117}
# {u'_id': u'fire_station', u'count': 106}
# {u'_id': u'toilets', u'count': 102}
# {u'_id': u'cafe', u'count': 98}
# {u'_id': u'post_office', u'count': 87}
# {u'_id': u'pharmacy', u'count': 83}
# {u'_id': u'bicycle_parking', u'count': 79}
# {u'_id': u'library', u'count': 76}
# {u'_id': u'shelter', u'count': 76}
# {u'_id': u'car_wash', u'count': 65}
# {u'_id': u'fountain', u'count': 51}

# %%
pipeline = [
    { "$match" : { "religion" : { "$exists" : 1 } } },
    { "$group" : { "_id" : "$religion",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } }
]
religions = db.cinci.aggregate(pipeline)

for item in religions:
    pprint.pprint(item)
# Out:
# {u'_id': u'christian', u'count': 1507}
# {u'_id': u'jewish', u'count': 21}
# {u'_id': u'muslim', u'count': 4}
# {u'_id': u'scientologist', u'count': 1}

# %%
pipeline = [
    { "$match" : { "denomination" : { "$exists" : 1 } } },
    { "$group" : { "_id" : "$denomination",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } }
]
denominations = db.cinci.aggregate(pipeline)

for item in denominations:
    pprint.pprint(item)
# Out:
# {u'_id': u'baptist', u'count': 256}
# {u'_id': u'catholic', u'count': 205}
# {u'_id': u'methodist', u'count': 121}
# {u'_id': u'presbyterian', u'count': 67}
# {u'_id': u'roman_catholic', u'count': 45}
# {u'_id': u'lutheran', u'count': 37}
# {u'_id': u'pentecostal', u'count': 17}
# {u'_id': u'protestant', u'count': 17}
# {u'_id': u'jehovahs_witness', u'count': 8}
# {u'_id': u'mormon', u'count': 6}
# {u'_id': u'episcopal', u'count': 6}
# {u'_id': u'orthodox', u'count': 3}
# {u'_id': u'christ_scientist', u'count': 3}
# {u'_id': u'evangelical', u'count': 3}
# {u'_id': u'church_of_christ', u'count': 2}
# {u'_id': u'salvation_army', u'count': 2}
# {u'_id': u'methodist; episcopal', u'count': 1}
# {u'_id': u'unitarian', u'count': 1}
# {u'_id': u'hasidic', u'count': 1}
# {u'_id': u'assemblies_of_god', u'count': 1}
# {u'_id': u'wesleyan', u'count': 1}
# {u'_id': u'swedenborgian', u'count': 1}
# {u'_id': u'presbyterian;episcopal', u'count': 1}
# {u'_id': u'seventh_day_adventist', u'count': 1}
# {u'_id': u'methodist_episcopal', u'count': 1}
# {u'_id': u'russian_orthodox', u'count': 1}
# {u'_id': u'haredi', u'count': 1}
# {u'_id': u'United Church of God', u'count': 1}
# {u'_id': u'modern_orthodox', u'count': 1}
# {u'_id': u'shaker', u'count': 1}
# {u'_id': u'no', u'count': 1}
# {u'_id': u'apostlic', u'count': 1}

# %% [markdown]
# ### Exploration of user participation

# %%
import pprint

pipeline = [
    { "$group" : { "_id" : "$created.user",
                   "count" : { "$sum" : 1 } } },
    { "$sort" : { "count" : -1 } }
]
users = db.cinci.aggregate(pipeline)

top_users = 0
top_user_edits = 0
for item in users:
    if item['count'] > 1000:
        pprint.pprint(item)
        top_users += 1
        top_user_edits += item['count']
# Out:
# {u'_id': u'Minh Nguyen', u'count': 899093}
# {u'_id': u'lrhill', u'count': 614469}
# {u'_id': u'woodpeck_fixbot', u'count': 344876}
# {u'_id': u'Nate_Wessel', u'count': 237463}
# {u'_id': u'bot-mode', u'count': 13464}
# {u'_id': u'drewp', u'count': 12134}
# {u'_id': u'Matt Currie', u'count': 12044}
# {u'_id': u'TIGERcnl', u'count': 11835}
# {u'_id': u'gmensch', u'count': 10499}
# {u'_id': u'MichaelGSmith', u'count': 10211}
# {u'_id': u'lightbulbsrwarm', u'count': 8282}
# {u'_id': u'reportingsjr', u'count': 6271}
# {u'_id': u'Chris Davis', u'count': 5881}
# {u'_id': u'mikecanann', u'count': 5173}
# {u'_id': u'errorcode', u'count': 5076}
# {u'_id': u'MountainAddict', u'count': 3781}
# {u'_id': u'Jeffrey Jakucyk', u'count': 3722}
# {u'_id': u'nickvet419', u'count': 3650}
# {u'_id': u'samely', u'count': 2732}
# {u'_id': u'aa9yh', u'count': 2643}
# {u'_id': u'NE2', u'count': 2328}
# {u'_id': u'silentcarto', u'count': 2089}
# {u'_id': u'Joeveralls', u'count': 1857}
# {u'_id': u'maxerickson', u'count': 1644}
# {u'_id': u'itspip', u'count': 1591}
# {u'_id': u'RoTide', u'count': 1413}
# {u'_id': u'Dr Kludge', u'count': 1193}
# {u'_id': u'MapYak', u'count': 1146}
# {u'_id': u'zephyr', u'count': 1144}
# {u'_id': u'DaveHansenTiger', u'count': 1078}

# %%
print "Number of users w/ more than 1000 edits: ", top_users
print "Total edits made by such users: ", top_user_edits

top_user_edits_perc = (top_user_edits * 100.0) / (nodes + ways)
top_users_perc = (top_users * 100.0) / len(user_list)
print top_user_edits_perc, "percent of all edits were made by", top_users_perc, "percent of users"
# Out:
# Number of users w/ more than 1000 edits:  30
# Total edits made by such users:  2228782
# 98.8063609325 percent of all edits were made by 5.30973451327 percent of users
